# %%
# !pip install datasets
from datasets import load_dataset
dataset = load_dataset("SemEvalWorkshop/sem_eval_2010_task_8")
print(dataset)
# Out:
# Requirement already satisfied: datasets in /opt/anaconda3/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'relation'],
#         num_rows: 8000
#     })
#     test: Dataset({
#         features: ['sentence', 'relation'],
#         num_rows: 2717
#     })
# })

# %%
import spacy
import re
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

def extract_context_words(sentences):
    """
    提取 <e1> 和 <e2> 之间的上下文词，支持多词实体
    """
    context_words_list = []
    nlp = spacy.load("en_core_web_sm")  # 加载 spaCy 仅一次

    for sentence in sentences:
        # 提取 <e1> 和 <e2> 实体
        e1_match = re.search(r'<e1>(.*?)</e1>', sentence)
        e2_match = re.search(r'<e2>(.*?)</e2>', sentence)

        if e1_match and e2_match:
            e1 = e1_match.group(1)
            e2 = e2_match.group(1)

            # 清除实体标签
            clean_sentence = re.sub(r'</?e1>', '', sentence)
            clean_sentence = re.sub(r'</?e2>', '', clean_sentence)

            # 使用 spaCy 分词
            doc = nlp(clean_sentence)
            tokens = [token.text for token in doc]

            # 将多词实体拆分成单词列表
            e1_tokens = e1.split()
            e2_tokens = e2.split()

            # 🔎 找到 e1 和 e2 的索引（支持多词实体）
            def find_sublist(sublist, lst):
                for i in range(len(lst) - len(sublist) + 1):
                    if lst[i:i + len(sublist)] == sublist:
                        return i
                return -1  # 未找到

            e1_index = find_sublist(e1_tokens, tokens)
            e2_index = find_sublist(e2_tokens, tokens)

            if e1_index == -1 or e2_index == -1:
                # 如果找不到实体索引，跳过该句子
                context_words_list.append([])
                continue

            # 确保 e1 在 e2 之前
            if e1_index > e2_index:
                e1_index, e2_index = e2_index, e1_index

            # 提取上下文词
            context_words = tokens[e1_index + len(e1_tokens): e2_index]
            context_words_list.append(context_words)
        else:
            context_words_list.append([])

    return context_words_list

def tfidf_weighted_w2v(context_words_list, vector_size=100, window=5, min_count=1):
    """
    📌 对上下文词进行 TF-IDF 加权的 Word2Vec 向量化
    ----------------------------------------------
    :param context_words_list: List[List[str]], 上下文词列表
    :param vector_size: int, Word2Vec 向量维度
    :param window: int, Word2Vec 窗口大小
    :param min_count: int, Word2Vec 最小词频
    :return: List[np.array], 每个上下文的向量表示
    """

    # 训练 Word2Vec 模型
    w2v_model = Word2Vec(sentences=context_words_list, vector_size=vector_size, window=window, min_count=min_count, workers=4)

    # 将上下文词拼接为字符串以适配 TF-IDF
    joined_contexts = [" ".join(context) for context in context_words_list]

    # 计算 TF-IDF
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_vectorizer.fit(joined_contexts)
    tfidf_vocab = tfidf_vectorizer.vocabulary_

    # 生成上下文词向量
    context_vectors = []
    for context in context_words_list:
        tfidf_weights = tfidf_vectorizer.transform([" ".join(context)]).toarray()[0]
        weighted_vectors = []

        for word in context:
            if word in w2v_model.wv and word in tfidf_vocab:
                tfidf_weight = tfidf_weights[tfidf_vocab[word]]
                weighted_vector = tfidf_weight * w2v_model.wv[word]
                weighted_vectors.append(weighted_vector)

        # 取平均向量作为该上下文的最终表示
        if weighted_vectors:
            context_vectors.append(np.mean(weighted_vectors, axis=0))
        else:
            context_vectors.append(np.zeros(vector_size))

    return context_vectors

# %%
# 示例数据 (符合 SemEval-2010 Task 8 格式)
sentences = dataset['train']['sentence']
# 1️⃣ 提取上下文词
context_words_list = extract_context_words(sentences)
for idx, context in enumerate(context_words_list):
    print(f"句子 {idx+1} 的上下文词: {context}")

# 2️⃣ 进行 TF-IDF 加权的 Word2Vec 向量化
context_vectors = tfidf_weighted_w2v(context_words_list)

# 3️⃣ 输出上下文词向量
for idx, vec in enumerate(context_vectors):
    print(f"句子 {idx+1} 的上下文向量:\n", vec)
# Out:
# 句子 1 的上下文词: ['of', 'antenna']
# 句子 2 的上下文词: ['was', 'carefully', 'wrapped', 'and', 'bound', 'into', 'the']
# 句子 3 的上下文词: ['of', 'a', 'keygen', 'uses', 'a']
# 句子 4 的上下文词: ['uprises', 'from', 'the']
# 句子 5 的上下文词: []
# 句子 6 的上下文词: ['that', 'is', 'Peru', "'s", 'largest']
# 句子 7 的上下文词: ['in', 'the', 'distal', 'part', 'of', 'the', 'stomach', 'caused', 'by', 'Helicobacter', 'pylori']
# 句子 8 的上下文词: ['have', 'been', 'moving', 'back', 'into']
# 句子 9 的上下文词: ['was', 'contained', 'in', 'a']
# 句子 10 的上下文词: ['was', 'pipetted', 'into', 'a', '25', 'mL', 'glass']
# 句子 11 的上下文词: ['collected', 'in', 'this']
# 句子 12 的上下文词: ['has', 'sunk', 'into']
# 句子 13 的上下文词: ['explaining', 'the']
# 句子 14 的上下文词: ['has', 'been', 'caused', 'by', 'water', 'hammer']
# 句子 15 的上下文词: []
# 句子 16 的上下文词: ['to', 'remind', 'them', 'about', 'the']
# 句子 17 的上下文词: ['finds', 'harmony', ',', 'sophistication', 'in', 'Appalachian']
# 句子 18 的上下文词: ["'s", 'products', 'have', 'included', 'flower', 'pots', ',', 'Finnish', 'rooster', '-', 'whistles', ',', 'pans', ',']
# 句子 19 的上下文词: []
# 句子 20 的上下文词: ['of', 'Panzer']
# 句子 21 的上下文词: ['of', 'the', 'power', 'and', 'rank', 'symbols', 'of', 'the', 'Continental', 'empires', 'was', 'gained', 'from', 'the', 'numerous', 'Germanic']
# 句子 22 的上下文词: ['of', 'her', 'own', 'rescued']
# 句子 23 的上下文词: [',', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', ',', 'also', 'caused', 'a']
# 句子 24 的上下文词: ['remain', 'pertinent', 'to', 'illuminating', 'contemporary']
# 句子 25 的上下文词: ['of', 'gamey']
# 句子 26 的上下文词: ['is', 'made', 'with', 'a']
# 句子 27 的上下文词: ['is', 'one', 'of', 'the', 'leading', 'causes', 'of']
# 句子 28 的上下文词: ['gives', 'details', 'on', '2004', 'in']
# 句子 29 的上下文词: ['dedicated', 'solely', 'to']
# 句子 30 的上下文词: ['of', 'the']
# 句子 31 的上下文词: ['in', 'a']
# 句子 32 的上下文词: ['from']
# 句子 33 的上下文词: ["'s", 'founding']
# 句子 34 的上下文词: ['of', 'containers', 'into', 'a']
# 句子 35 的上下文词: ['in', 'the']
# 句子 36 的上下文词: ['economically', 'from', 'OTEC']
# 句子 37 的上下文词: ['ran', 'into', 'Senate']
# 句子 38 的上下文词: ['are', 'divided', 'into']
# 句子 39 的上下文词: ['is', 'one', 'of', 'the', 'main', 'causes', 'of']
# 句子 40 的上下文词: ['swap', 'content', 'via', 'widgets', 'with', 'the', 'help', 'of', 'the', 'newsgator']
# 句子 41 的上下文词: ['that', 'caused', 'the']
# 句子 42 的上下文词: ['was', 'discovered', 'inside', 'a', 'bed', 'settee']
# 句子 43 的上下文词: ['of', 'brackish']
# 句子 44 的上下文词: ['was', 'released', 'from']
# 句子 45 的上下文词: ['are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a']
# 句子 46 的上下文词: ['use']
# 句子 47 的上下文词: ['proposed', 'assessing', 'infinitival', 'complements', 'through']
# 句子 48 的上下文词: ['is', 'caused', 'by', 'a']
# 句子 49 的上下文词: ['to', 'consolidated', 'financial']
# 句子 50 的上下文词: []
# 句子 51 的上下文词: ['from', 'the', 'atomic']
# 句子 52 的上下文词: []
# 句子 53 的上下文词: ['arose', 'from', 'an', 'extensive']
# 句子 54 的上下文词: ['from']
# 句子 55 的上下文词: ['of']
# 句子 56 的上下文词: ['around']
# 句子 57 的上下文词: []
# 句子 58 的上下文词: ['about', 'the', 'relative']
# 句子 59 的上下文词: ['with', 'red', 'bands', 'on', 'the', 'bodice', 'was', 'in', 'a']
# 句子 60 的上下文词: ['with', 'Lyons', 'concerns', 'the']
# 句子 61 的上下文词: ['have', 'been', 'moving', 'into', 'the']
# 句子 62 的上下文词: []
# 句子 63 的上下文词: ['of', 'fluorite']
# 句子 64 的上下文词: ['was', 'sealed', 'in']
# 句子 65 的上下文词: ['has', 'been', 'found', 'in', 'a', 'beef']
# 句子 66 的上下文词: ['of', 'the', 'undisciplined', 'Gaelic']
# 句子 67 的上下文词: ['left', 'her', 'native', 'paradise']
# 句子 68 的上下文词: ['makes', 'a', 'compelling']
# 句子 69 的上下文词: ['into', 'the']
# 句子 70 的上下文词: ['ensued', 'from', 'angry', 'and', 'injured']
# 句子 71 的上下文词: ['is', 'the', 'biggest', 'ever', 'caused', 'by', 'the']
# 句子 72 的上下文词: ['of', 'mindless']
# 句子 73 的上下文词: ['inside', 'WTC', 'was', 'caused', 'by', 'exploding']
# 句子 74 的上下文词: ['from', 'the', 'knockout', 'mouse', 'bladder', 'is', 'migrating', 'into', 'the', 'transplanted']
# 句子 75 的上下文词: ['was', 'removed', 'from', 'his']
# 句子 76 的上下文词: ['caused', 'by', 'the']
# 句子 77 的上下文词: ['of', 'nature', "'s", 'gift', 'has', 'been', 'reflected', 'in']
# 句子 78 的上下文词: ['decided', 'the', 'objection', 'by', 'making', 'the', 'instalment']
# 句子 79 的上下文词: ['triggered', 'by', 'the', 'rock']
# 句子 80 的上下文词: ['and', 'fire', 'caused', 'due', 'to']
# 句子 81 的上下文词: ['to', 'take', 'control', 'of', 'the']
# 句子 82 的上下文词: ['of', 'new']
# 句子 83 的上下文词: ['makes', 'a', 'ding', 'ding', 'ding']
# 句子 84 的上下文词: ['of']
# 句子 85 的上下文词: ['created', 'by', 'an', 'unregulated']
# 句子 86 的上下文词: ['of', 'the']
# 句子 87 的上下文词: ['was', 'dropped', 'into', 'the']
# 句子 88 的上下文词: ['caused', 'by', 'the', '1693', 'Catania']
# 句子 89 的上下文词: ['caused', 'by', 'the', 'responsible', 'police']
# 句子 90 的上下文词: ['have', 'been', 'published', 'in', 'a', 'special']
# 句子 91 的上下文词: ['who', 'alarmed', 'fellow', 'passengers', 'by', 'talking', 'about', 'terrorist', 'threats', 'on', 'a', 'cellphone', 'was', 'pulled', 'from', 'the']
# 句子 92 的上下文词: ['in', 'the']
# 句子 93 的上下文词: ['was', 'started', 'from', 'the', 'uncomplexed', 'x', '-', 'ray']
# 句子 94 的上下文词: ['plays', 'games', 'on', 'a', 'portable']
# 句子 95 的上下文词: ['arose', 'from', 'an']
# 句子 96 的上下文词: ['of', 'the', 'cement', 'truck', 'cleaned', 'the', 'loading', 'chute', 'on', 'his', 'truck', 'with', 'a', 'truck', '-', 'mounted', 'water']
# 句子 97 的上下文词: ['triggered', 'by', 'the', '1929', 'Wall', 'Street']
# 句子 98 的上下文词: ['of', 'Wu']
# 句子 99 的上下文词: ['and', 'inflammation', 'caused', 'by', 'the']
# 句子 100 的上下文词: ['is', 'produced', 'by', 'the']
# 句子 101 的上下文词: ['improvised', 'by', 'an']
# 句子 102 的上下文词: ['to', 'the']
# 句子 103 的上下文词: ['caused', 'by', 'Polymorph', 'by', '40', '%', 'at', 'max', 'rank', ',', 'though', 'the', 'threat', 'caused', 'by', 'the']
# 句子 104 的上下文词: ['uses', 'a', 'high', 'level']
# 句子 105 的上下文词: ['are', 'caused', 'by', 'the']
# 句子 106 的上下文词: ['in', 'a', 'fruit']
# 句子 107 的上下文词: ['of']
# 句子 108 的上下文词: ["'s", 'sewing']
# 句子 109 的上下文词: ['per', 'quart', 'was', 'dropped', 'into', 'a']
# 句子 110 的上下文词: ['of', 'the', 'Renaissance', 'master', 'is', 'hidden', 'in', 'a']
# 句子 111 的上下文词: [',', 'which', 'was', 'in', 'a']
# 句子 112 的上下文词: ['was', 'distilled', 'from', 'an', 'allraline']
# 句子 113 的上下文词: [',', 'over', '850']
# 句子 114 的上下文词: []
# 句子 115 的上下文词: ["'"]
# 句子 116 的上下文词: []
# 句子 117 的上下文词: ['of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a']
# 句子 118 的上下文词: ['of']
# 句子 119 的上下文词: ['of', 'the']
# 句子 120 的上下文词: ['of']
# 句子 121 的上下文词: ['was', 'also', 'the', 'subject', 'of', 'an', 'unsuccessful']
# 句子 122 的上下文词: ['from', 'the', 'low', 'temperature', 'steam', 'reforming']
# 句子 123 的上下文词: ['moved', 'into', 'the']
# 句子 124 的上下文词: ['to', 'answer', 'in', 'an', 'interview', 'relates', 'to']
# 句子 125 的上下文词: ['has', 'been', 'narrated', 'in', 'prophet', "'s", 'early']
# 句子 126 的上下文词: ['who', 'tried', 'to', 'steal', 'the', 'truck', 'broke', 'the', 'igenition', 'with']
# 句子 127 的上下文词: ['of', 'heavy']
# 句子 128 的上下文词: ['into', 'the']
# 句子 129 的上下文词: ['on', 'Monday', 'caused']
# 句子 130 的上下文词: ['have', 'been', 'dropped', 'into', 'the']
# 句子 131 的上下文词: ['also', 'hailed', 'from', 'this', 'infamous']
# 句子 132 的上下文词: ['of', 'a']
# 句子 133 的上下文词: ['develops', 'new', 'business']
# 句子 134 的上下文词: ['were', 'manufactured', 'at', 'the']
# 句子 135 的上下文词: ['of', 'the', 'National']
# 句子 136 的上下文词: ['from']
# 句子 137 的上下文词: ['from', 'long', '-', 'forgotten']
# 句子 138 的上下文词: ['of', 'interlocking']
# 句子 139 的上下文词: ['from', 'roof', 'leaks', ',', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the']
# 句子 140 的上下文词: ['of']
# 句子 141 的上下文词: ['of', 'struvite']
# 句子 142 的上下文词: ['was', 'making', 'his', 'greatest']
# 句子 143 的上下文词: ['of', 'Europe', "'s"]
# 句子 144 的上下文词: ['of', 'the', 'heart', 'was', 'extracted', 'from', 'the', 'intensity']
# 句子 145 的上下文词: ['from', 'the']
# 句子 146 的上下文词: ['of']
# 句子 147 的上下文词: ['of', 'articulated']
# 句子 148 的上下文词: ['into']
# 句子 149 的上下文词: ['for']
# 句子 150 的上下文词: ['was', 'found', 'put', 'inside', 'the']
# 句子 151 的上下文词: ['was', 'manufactured', 'in', 'a', 'small', 'wood']
# 句子 152 的上下文词: ['pushed', 'to', 'the', 'coast', 'resulted', 'in']
# 句子 153 的上下文词: ['in', 'this', 'book', 'investigate']
# 句子 154 的上下文词: ['to', 'the']
# 句子 155 的上下文词: ['was', 'generated', 'from', 'an', 'up', '-', 'draft']
# 句子 156 的上下文词: ['have', 'travelled', 'into']
# 句子 157 的上下文词: ['which', 'originated', 'from', 'the', 'Dutch', 'which', 'were', 'the', 'first']
# 句子 158 的上下文词: []
# 句子 159 的上下文词: ['has', 'to', 'do', 'with']
# 句子 160 的上下文词: ['over', 'the', 'circles', "'"]
# 句子 161 的上下文词: []
# 句子 162 的上下文词: ['which', 'is', 'the', 'basic', 'ingredient', 'used', 'for', 'making']
# 句子 163 的上下文词: ['calibrates', 'the', 'microscope', 'with', 'a', 'fluorescence', 'lifetime']
# 句子 164 的上下文词: ['comprises', 'the', 'southeastern']
# 句子 165 的上下文词: ['is', 'the', 'source', 'of', 'an', 'electric']
# 句子 166 的上下文词: ['however', 'has', 'been', 'caused', 'by', 'the']
# 句子 167 的上下文词: ['was', 'in', 'a']
# 句子 168 的上下文词: ['was', 'distilled', 'from', 'an', 'Arbuzov']
# 句子 169 的上下文词: ['of', 'deadly']
# 句子 170 的上下文词: ['relating', 'the', 'early']
# 句子 171 的上下文词: ['after', 'the']
# 句子 172 的上下文词: [',', 'and', 'the', 'steamer', 'stopped', 'her']
# 句子 173 的上下文词: ['that', 'peels', 'the', 'potatoes', 'with', 'a']
# 句子 174 的上下文词: []
# 句子 175 的上下文词: ['left', 'the']
# 句子 176 的上下文词: ['of', 'nine']
# 句子 177 的上下文词: ['was', 'contained', 'in', 'a', 'semi-', 'permeable']
# 句子 178 的上下文词: ['into']
# 句子 179 的上下文词: ['consisted', 'of', 'plowing', 'the', 'crop', 'with', 'a', 'double', '-', 'shovel']
# 句子 180 的上下文词: ['offers', 'a']
# 句子 181 的上下文词: ['caused', 'by', 'a', 'BBC']
# 句子 182 的上下文词: ['of', 'the']
# 句子 183 的上下文词: ['into']
# 句子 184 的上下文词: ['into']
# 句子 185 的上下文词: ["'s"]
# 句子 186 的上下文词: ['of']
# 句子 187 的上下文词: ['attaches', 'a']
# 句子 188 的上下文词: ['were', 'denoted', 'by']
# 句子 189 的上下文词: ['release', 'from', 'the', 'Chernobyl']
# 句子 190 的上下文词: ['full', 'of']
# 句子 191 的上下文词: ['held', 'the', 'mouse', 'in', 'its']
# 句子 192 的上下文词: ['was', 'put', 'inside', 'the', 'upper', 'part', 'of', 'the', 'rock']
# 句子 193 的上下文词: ['who', 'drew', 'a']
# 句子 194 的上下文词: ['into', 'his', 'duffel']
# 句子 195 的上下文词: ['of', 'terrific']
# 句子 196 的上下文词: ['of', 'the']
# 句子 197 的上下文词: ['from', 'the', 'largely', 'forgotten']
# 句子 198 的上下文词: ['caused', 'by', 'the']
# 句子 199 的上下文词: ['by', 'a', 'Virginia']
# 句子 200 的上下文词: ['is', 'built', 'up', 'of', 'many']
# 句子 201 的上下文词: ['approached', 'the', 'big', 'cat', 'with', 'a']
# 句子 202 的上下文词: ['is', 'from', 'the', 'New', 'York', 'public']
# 句子 203 的上下文词: ['caused', 'a', 'major', 'traffic']
# 句子 204 的上下文词: ['whose']
# 句子 205 的上下文词: ['was', 'in', 'a']
# 句子 206 的上下文词: ['caused', 'by', 'the', 'indicated']
# 句子 207 的上下文词: ['of', 'that']
# 句子 208 的上下文词: ['of', 'historical', 'resources', ',', 'has', 'completed', 'a', 'picture']
# 句子 209 的上下文词: ['into', 'host', 'variable']
# 句子 210 的上下文词: ['arrive', 'to']
# 句子 211 的上下文词: []
# 句子 212 的上下文词: ["'s"]
# 句子 213 的上下文词: []
# 句子 214 的上下文词: []
# 句子 215 的上下文词: ['of', 'the', 'diaphragm', 'are', 'caused', 'by', 'stimulation', 'of', 'the', 'vagus', 'nerve', 'either', 'by', 'the', 'brain', 'or', 'by']
# 句子 216 的上下文词: ['drive', 'from']
# 句子 217 的上下文词: ['is', 'derived', 'from', 'a', 'static']
# 句子 218 的上下文词: ['dug', 'a', 'large']
# 句子 219 的上下文词: ['providing']
# 句子 220 的上下文词: [',', 'frightened', 'of', 'losing', 'votes', ',', 'resolved', 'the', 'crisis', 'through']
# 句子 221 的上下文词: []
# 句子 222 的上下文词: ['of', 'turkey']
# 句子 223 的上下文词: ['are', 'caused', 'by', 'a']
# 句子 224 的上下文词: ['was', 'manufactured', 'in', 'a', 'cost', 'effective', 'thin', 'film']
# 句子 225 的上下文词: ['of', 'such']
# 句子 226 的上下文词: ['of', 'the', '10', 'Most', 'Beautiful', 'Women', 'posted', 'on', 'the', 'official', 'Web', 'site', 'of', 'the', '2009', 'Australian', 'Open', 'was', 'filled', 'with', 'sleek', ',', 'thin']
# 句子 227 的上下文词: []
# 句子 228 的上下文词: ['pours', 'on', 'a', 'liquid', 'while', 'the', 'other', 'man', 'stirs', 'the', 'mixture', 'with', 'a', 'wooden']
# 句子 229 的上下文词: ['of', 'different', 'social']
# 句子 230 的上下文词: ['are', 'migrating', 'into']
# 句子 231 的上下文词: ['preserved', 'in', 'a']
# 句子 232 的上下文词: ['contains', 'tungsten', '-', 'tipped']
# 句子 233 的上下文词: ['into']
# 句子 234 的上下文词: ['had', 'left', 'the']
# 句子 235 的上下文词: ['analyses', 'the', 'adaptation']
# 句子 236 的上下文词: ['by', 'the', 'colonial']
# 句子 237 的上下文词: ['to', 'the', 'next']
# 句子 238 的上下文词: ['assists', 'the']
# 句子 239 的上下文词: ['accidentally', 'went', 'into', 'the', 'girl', "'s"]
# 句子 240 的上下文词: ['is', 'stored', 'in', 'the', 'proper']
# 句子 241 的上下文词: ['were', 'spent', 'describing', 'the', 'clubs']
# 句子 242 的上下文词: []
# 句子 243 的上下文词: ['of']
# 句子 244 的上下文词: ['into', 'promoting', 'low', '-', 'alcohol']
# 句子 245 的上下文词: ['was', 'stored', 'in']
# 句子 246 的上下文词: ['were', 'released', 'into', 'the']
# 句子 247 的上下文词: ['of', 'the', 'court', 'is', 'completed', 'by', 'the']
# 句子 248 的上下文词: ['lost', 'in', 'the', 'ocean', 'was', 'found', 'in', 'a', 'cod']
# 句子 249 的上下文词: ['advertised', 'a', 'two', '-', 'week']
# 句子 250 的上下文词: ['arose', 'from', 'the']
# 句子 251 的上下文词: ['incorporates', 'new', 'research']
# 句子 252 的上下文词: ['swim', 'in', 'a']
# 句子 253 的上下文词: ['have', 'been', 'exported', 'to', 'a', 'single']
# 句子 254 的上下文词: ['used', 'the', 'newly', '-', 'developed']
# 句子 255 的上下文词: ['in', 'a']
# 句子 256 的上下文词: ['of', 'great', 'blue']
# 句子 257 的上下文词: ['is', 'pushed', 'into', 'the']
# 句子 258 的上下文词: ['of', 'Five', 'Bells', 'has', 'been', 'sent', 'to', 'poet', 'union']
# 句子 259 的上下文词: ['and', 'large', 'yachts', 'have', 'much', 'more', 'sophisticated']
# 句子 260 的上下文词: ['killed', 'the', 'victim', 'with', 'a']
# 句子 261 的上下文词: ['of', 'whale']
# 句子 262 的上下文词: ['and', 'placing', 'the', 'capsule', 'in', 'a', 'message']
# 句子 263 的上下文词: ['was', 'made', 'with']
# 句子 264 的上下文词: ['illustrating', 'the']
# 句子 265 的上下文词: [',', 'having', 'devised', 'the']
# 句子 266 的上下文词: ['has', 'assembled', 'a', '$', '230', 'million', 'incentive']
# 句子 267 的上下文词: ['full', 'of']
# 句子 268 的上下文词: ['is', 'coiled', 'in', 'a']
# 句子 269 的上下文词: ['caused', 'a']
# 句子 270 的上下文词: ['have', 'been', 'illustrated', 'in', 'the']
# 句子 271 的上下文词: ['of', 'the', 'chief', 'of', 'the']
# 句子 272 的上下文词: ['comprises', 'some', 're', '-', 'issues', 'of', 'the', 'previous', 'books', ',', 'as', 'well', 'as', 'new']
# 句子 273 的上下文词: ['also', 'put', 'up', 'a']
# 句子 274 的上下文词: ['comprises', 'the']
# 句子 275 的上下文词: ['from', 'everyday']
# 句子 276 的上下文词: ['of']
# 句子 277 的上下文词: ['into']
# 句子 278 的上下文词: ['descended', 'from', 'an', 'aquatic']
# 句子 279 的上下文词: ['of', 'the']
# 句子 280 的上下文词: ['into', 'the', 'tattoo']
# 句子 281 的上下文词: ['obtained', 'from', 'vitrified', ',', 'warmed']
# 句子 282 的上下文词: ['was', 'sent', 'from']
# 句子 283 的上下文词: ['is', 'one', 'of', 'the', 'leading', 'causes', 'of']
# 句子 284 的上下文词: [',', 'departs', 'from', 'an']
# 句子 285 的上下文词: ['into', 'a', 'fairly', 'wide', '-', 'necked', 'wine']
# 句子 286 的上下文词: ['from', 'nasal', 'and']
# 句子 287 的上下文词: ['through', 'an', 'STS']
# 句子 288 的上下文词: ['won', 'the', 'Hispanic', 'vote', 'with']
# 句子 289 的上下文词: ['was', 'hidden', 'in', 'a']
# 句子 290 的上下文词: ['of', 'bright', 'orange']
# 句子 291 的上下文词: ['into', 'the']
# 句子 292 的上下文词: ['moved', 'into', 'the', 'deep']
# 句子 293 的上下文词: ['of', 'the']
# 句子 294 的上下文词: ['was', 'found', 'in', 'a']
# 句子 295 的上下文词: ['originally', 'was', 'inside', 'a']
# 句子 296 的上下文词: ['establishes', 'the']
# 句子 297 的上下文词: ['was', 'sealed', 'in', 'the', 'original']
# 句子 298 的上下文词: ['rests', 'in', 'a']
# 句子 299 的上下文词: ['stuffed', 'in', 'a']
# 句子 300 的上下文词: ['is', 'moving', 'into', 'new']
# 句子 301 的上下文词: ['broke', 'the', 'commandment', 'with', 'priestly']
# 句子 302 的上下文词: ['developed', 'from', 'the']
# 句子 303 的上下文词: ['of', 'the']
# 句子 304 的上下文词: ['in', 'a', 'non', '-', 'food']
# 句子 305 的上下文词: ['into', 'the']
# 句子 306 的上下文词: ['plowing', 'with', 'a']
# 句子 307 的上下文词: []
# 句子 308 的上下文词: ['were', 'in', 'a']
# 句子 309 的上下文词: ['encloses', 'a', 'venter', 'canal']
# 句子 310 的上下文词: [',', 'as', 'defined', 'earlier', 'in', 'this']
# 句子 311 的上下文词: ['arrives', 'from', 'a', 'distant']
# 句子 312 的上下文词: ['of', 'a', '10', '-', 'year', '-', 'old', 'school', 'boy', ',', 'a', 'resident', 'of', 'Jaylal', 'Munshi', 'Ka', 'Rasta', 'in', 'Nahargarh', 'area', ',', 'was', 'found', 'in', 'a']
# 句子 313 的上下文词: ['of']
# 句子 314 的上下文词: [',', 'Holy', 'Soap', ',', 'dedicated', 'to', 'popular', 'television']
# 句子 315 的上下文词: ['consists', 'of', 'two']
# 句子 316 的上下文词: ['started', 'when', 'the']
# 句子 317 的上下文词: ['who', 'specialises', 'in', 'love']
# 句子 318 的上下文词: ['of', 'the', 'aquarium', 'was', 'derived', 'from', 'a', 'public']
# 句子 319 的上下文词: ['into', 'the', 'same']
# 句子 320 的上下文词: ['from']
# 句子 321 的上下文词: ['originated', 'in', 'an', 'extensive']
# 句子 322 的上下文词: ['describes', 'the']
# 句子 323 的上下文词: ['into', 'the', 'old', 'tin']
# 句子 324 的上下文词: ['of', 'the']
# 句子 325 的上下文词: ['of', 'this']
# 句子 326 的上下文词: ['from', 'the']
# 句子 327 的上下文词: ['by', 'letting', 'down', 'the']
# 句子 328 的上下文词: ['devoted', 'exclusively', 'to', 'the']
# 句子 329 的上下文词: ['defining']
# 句子 330 的上下文词: []
# 句子 331 的上下文词: ['lit', 'the']
# 句子 332 的上下文词: ['of', 'information', 'pulses', 'from', 'a']
# 句子 333 的上下文词: ['of', 'bantam']
# 句子 334 的上下文词: ['of', 'the', 'inner', 'artwork', 'of', 'the', 'record', 'was', 'analysed', 'in', 'an']
# 句子 335 的上下文词: ['with', 'the', 'flight', 'attendant', 'caused', 'a']
# 句子 336 的上下文词: ['build', 'the']
# 句子 337 的上下文词: ['behind', 'it', 'was', 'in', 'a']
# 句子 338 的上下文词: ['in', 'the']
# 句子 339 的上下文词: ['is', 'the', 'product', 'of', 'the', 'bcr', '/', 'abl', 'hybrid']
# 句子 340 的上下文词: ['was', 'to', 'report', 'on', 'the']
# 句子 341 的上下文词: ['was', 'full', 'of', 'fine']
# 句子 342 的上下文词: ['of']
# 句子 343 的上下文词: [',', 'which', 'is', 'put', 'inside', 'a', 'wooden']
# 句子 344 的上下文词: ['of', 'the', 'signal', 'originates', 'from', 'the']
# 句子 345 的上下文词: ['caused', 'by', 'the']
# 句子 346 的上下文词: ['reached', 'the', 'goal', 'using', 'a', 'smaller', 'number', 'of', 'internal']
# 句子 347 的上下文词: ['of', 'the', 'health']
# 句子 348 的上下文词: ['are', 'caused', 'by']
# 句子 349 的上下文词: ['writes', 'a', 'whole', 'number', 'less', 'than', '50000', 'on', 'the']
# 句子 350 的上下文词: ['of', 'white']
# 句子 351 的上下文词: ['falls', 'in']
# 句子 352 的上下文词: ['and', 'smoke', 'cause', 'flight']
# 句子 353 的上下文词: ['are', 'caused', 'by', 'water', '-', 'borne']
# 句子 354 的上下文词: ['produced', 'by', 'the', 'modern']
# 句子 355 的上下文词: ['flow', 'into', 'unit', 'trust', '-', 'linked']
# 句子 356 的上下文词: ['has', 'constructed']
# 句子 357 的上下文词: ['of', 'American', 'roadside', 'diners', ',', 'cinemas', 'and', 'motels', 'is', 'the', 'subject', 'of', 'a', 'new', 'photography']
# 句子 358 的上下文词: ['through', 'the', 'reset']
# 句子 359 的上下文词: ['caused', 'by', 'the']
# 句子 360 的上下文词: ['includes', 'an', 'on', '-', 'off', '-', 'on']
# 句子 361 的上下文词: ['arrives', 'from', 'the']
# 句子 362 的上下文词: ['(', 'or', 'midbrain', ')', 'comprises', 'the']
# 句子 363 的上下文词: ['to', 'early']
# 句子 364 的上下文词: ['is', 'scratched', 'in', 'a']
# 句子 365 的上下文词: ['is', 'travelling', 'into', 'the']
# 句子 366 的上下文词: ['breaks', 'open', 'the', 'egg', 'with', 'a', 'sharp']
# 句子 367 的上下文词: ['later', 'in', 'the']
# 句子 368 的上下文词: ['was', 'in', 'a']
# 句子 369 的上下文词: ['and', 'poured']
# 句子 370 的上下文词: ['that', 'is', 'in', 'the', 'air', 'evaporated', 'from', 'the', 'surface', 'of', 'the']
# 句子 371 的上下文词: ['produced', 'by', 'a']
# 句子 372 的上下文词: ['had', 'left', 'the']
# 句子 373 的上下文词: ['was', 'in', 'a']
# 句子 374 的上下文词: ['made', 'the', '75', '-', 'millionth', 'ton', 'of']
# 句子 375 的上下文词: ['regulated', 'the', 'temperature', 'using', 'an', 'odoff']
# 句子 376 的上下文词: ['triggered', 'by', 'the']
# 句子 377 的上下文词: ['of', 'full', 'forty']
# 句子 378 的上下文词: ['is', 'composed', 'chiefly', 'of', 'the', 'quadriceps', 'femoris', '(', 'rectus', 'femoris', ',', 'vastus', 'lateralis', ',', 'vastus', 'intermedius', ',', 'vastus', 'medialis', ')', ',', 'quadriceps', 'tendon', ',']
# 句子 379 的上下文词: ['with']
# 句子 380 的上下文词: ['caused', 'a']
# 句子 381 的上下文词: ['triggered', 'by', 'the']
# 句子 382 的上下文词: ['are', 'under']
# 句子 383 的上下文词: ['grows', 'a', 'big', 'thick']
# 句子 384 的上下文词: ['in', 'his']
# 句子 385 的上下文词: ['into', 'the']
# 句子 386 的上下文词: ['published', 'political']
# 句子 387 的上下文词: ['of', 'the', 'long', '-', 'awaited']
# 句子 388 的上下文词: ['was', 'locked', 'in', 'a', 'glass']
# 句子 389 的上下文词: [',', 'written', 'by', 'the']
# 句子 390 的上下文词: ['have', 'migrated', 'into', 'the']
# 句子 391 的上下文词: ['caused', 'delays', 'and']
# 句子 392 的上下文词: ['for', 'The', 'New', 'York', 'Times', ',', 'has', 'just', 'completed', 'a']
# 句子 393 的上下文词: ['of', 'his', 'travels', 'were', 'related', 'in', 'a', 'succession', 'of']
# 句子 394 的上下文词: ['is', 'going', 'away', 'from', 'the', 'display']
# 句子 395 的上下文词: ['is', 'a', 'natural', 'cure', 'for']
# 句子 396 的上下文词: ['of']
# 句子 397 的上下文词: ['originating', 'in', 'the', 'sphenoid']
# 句子 398 的上下文词: [',', 'a', 'seashore', 'tide']
# 句子 399 的上下文词: ['is', 'exported', 'to', 'the']
# 句子 400 的上下文词: ['on', 'the', 'spinal', 'cord', 'that', 'has', 'been', 'caused', 'by', 'a', 'herniated', 'or', 'bulging']
# 句子 401 的上下文词: ['went', 'into']
# 句子 402 的上下文词: [',', 'and', 'by', '1894', 'the', 'brothers', "'"]
# 句子 403 的上下文词: ['at', 'the', 'surface', 'moved', 'southward', 'into', 'the']
# 句子 404 的上下文词: ['of']
# 句子 405 的上下文词: ['of', 'king']
# 句子 406 的上下文词: ['on', 'a', 'square']
# 句子 407 的上下文词: ['composed', 'of']
# 句子 408 的上下文词: ['is', 'the', 'source', 'of', 'the', 'brilliant', 'red', 'dye']
# 句子 409 的上下文词: ['acts', 'as', 'a', 'great', 'hair', 'of', 'the']
# 句子 410 的上下文词: ['has', 'run', 'into', 'a', 'financial']
# 句子 411 的上下文词: ['of', 'the']
# 句子 412 的上下文词: ['plays', 'her', 'violin', 'on', 'a', 'pogo']
# 句子 413 的上下文词: ['carefully', 'applies', 'the']
# 句子 414 的上下文词: ['was', 'inside', 'a']
# 句子 415 的上下文词: ["'s"]
# 句子 416 的上下文词: []
# 句子 417 的上下文词: []
# 句子 418 的上下文词: ['in', 'a']
# 句子 419 的上下文词: []
# 句子 420 的上下文词: ['of']
# 句子 421 的上下文词: ['that', 'has', 'been', 'caused', 'by', 'the']
# 句子 422 的上下文词: ['has', 'applied', 'the']
# 句子 423 的上下文词: ['was', 'contained', 'in', 'a', 'plain']
# 句子 424 的上下文词: ['have', 'been', 'prepared', 'on']
# 句子 425 的上下文词: ['was', 'excluded', 'from', 'his', 'own']
# 句子 426 的上下文词: ['(', 'Shirley', 'Temple', ')', 'by', 'a', 'wealthy']
# 句子 427 的上下文词: ['inquires', 'into', 'the']
# 句子 428 的上下文词: ['after', 'the']
# 句子 429 的上下文词: ['triggered', 'by', 'the']
# 句子 430 的上下文词: ['in', 'the', 'molecular']
# 句子 431 的上下文词: ['is', 'a', 'review', 'of', 'frequency', 'stability', 'measurement']
# 句子 432 的上下文词: ['is', 'one', 'of', 'the', 'leading', 'causes', 'of', 'irreversible']
# 句子 433 的上下文词: ['assisted', 'with', 'the']
# 句子 434 的上下文词: ['has', 'been', 'concerning', 'primarily', 'assembly']
# 句子 435 的上下文词: ['was', 'from', 'a', 'window']
# 句子 436 的上下文词: ['for']
# 句子 437 的上下文词: ['by', 'the', 'Senate']
# 句子 438 的上下文词: ['were', 'blown', 'into']
# 句子 439 的上下文词: ['carefully', 'chose']
# 句子 440 的上下文词: ['of', 'the']
# 句子 441 的上下文词: ['in', 'a']
# 句子 442 的上下文词: [',', 'the']
# 句子 443 的上下文词: ['that', 'had', 'been', 'caused', 'by', 'the']
# 句子 444 的上下文词: ['blooms', 'out', 'of', 'the', 'muddy']
# 句子 445 的上下文词: ['of', 'live']
# 句子 446 的上下文词: ['of', 'festive']
# 句子 447 的上下文词: ['behind', 'the', 'formation', 'of', 'the', 'fund', 'came', 'from', 'a', 'wounded', 'Vietnam']
# 句子 448 的上下文词: ['from', 'the']
# 句子 449 的上下文词: ['of']
# 句子 450 的上下文词: ['of']
# 句子 451 的上下文词: ['first', 'cleaned', 'the', 'floor', 'with', 'a', 'company', '-', 'approved', 'cleaning']
# 句子 452 的上下文词: ['includes', 'an', 'audio', 'and', 'video']
# 句子 453 的上下文词: ['was', 'caused', 'by', 'the', 'plaintiff', "'s", 'own']
# 句子 454 的上下文词: ['arrived', 'in', 'a']
# 句子 455 的上下文词: ['of']
# 句子 456 的上下文词: ['from', 'the', 'Amazon', 'powered', 'a']
# 句子 457 的上下文词: ['centers', 'on', 'a']
# 句子 458 的上下文词: ['consisting', 'of', 'rectangular']
# 句子 459 的上下文词: ['by', 'the', 'senior', 'dental']
# 句子 460 的上下文词: ['are', 'carried', 'into', 'the']
# 句子 461 的上下文词: ['define']
# 句子 462 的上下文词: ['after', 'the']
# 句子 463 的上下文词: []
# 句子 464 的上下文词: ['catch', 'the', 'shad', 'with', 'gill']
# 句子 465 的上下文词: ['of', 'the']
# 句子 466 的上下文词: ['of', 'their']
# 句子 467 的上下文词: ['centers', 'around', 'a', 'young']
# 句子 468 的上下文词: []
# 句子 469 的上下文词: ['company', 'imports', 'oil', 'to', 'some']
# 句子 470 的上下文词: ['is', 'going', 'on', 'well', 'away', 'from', 'the', 'most', 'visible']
# 句子 471 的上下文词: ['drank', 'the', 'alcohol', 'out', 'of']
# 句子 472 的上下文词: ['emerging', 'from', 'the']
# 句子 473 的上下文词: ['accessed', 'the', 'vault', 'with', 'the']
# 句子 474 的上下文词: ['was', 'a', 'part', 'of', 'the', 'Romulan', 'mining']
# 句子 475 的上下文词: []
# 句子 476 的上下文词: ['of', 'the']
# 句子 477 的上下文词: ['developed', 'from', 'the']
# 句子 478 的上下文词: ["'s", 'reasons', 'for', 'creating', 'a']
# 句子 479 的上下文词: ['of', 'the']
# 句子 480 的上下文词: ['put', 'up', 'a']
# 句子 481 的上下文词: ['filters', 'the', 'smoke', 'through']
# 句子 482 的上下文词: ['are', 'under', 'way', 'on', 'issues', 'such', 'as']
# 句子 483 的上下文词: ['of']
# 句子 484 的上下文词: ['caused', 'a', 'brief']
# 句子 485 的上下文词: []
# 句子 486 的上下文词: ['searched', 'the', 'vessel', 'with', 'the']
# 句子 487 的上下文词: ['are', 'published', 'on', 'this']
# 句子 488 的上下文词: ['fine', '-', 'tunes', 'your', 'hair', 'color', 'without', 'causing', 'excessive', 'damage', 'by', 'using']
# 句子 489 的上下文词: ['locate', 'these', 'cities', 'on', 'the', 'large', 'map', '(', 'B2', ')', 'with', 'assistance', 'from', 'the', 'teacher', '(', 'B14', ')', 'marking', 'them', 'with', 'colored']
# 句子 490 的上下文词: ['in', 'a', 'hamper']
# 句子 491 的上下文词: ['of']
# 句子 492 的上下文词: ['was', 'in', 'a']
# 句子 493 的上下文词: ['after', 'making', 'a', 'cut', 'of', 'the', 'stem', 'with', 'a', 'clean', ',', 'sharp']
# 句子 494 的上下文词: []
# 句子 495 的上下文词: ['downstairs', 'in', 'the']
# 句子 496 的上下文词: ['receives', 'the', 'call', 'through', 'a', 'miniature', 'radio']
# 句子 497 的上下文词: ['containing', 'stale']
# 句子 498 的上下文词: ['is', 'inherited', 'to', 'the', 'next']
# 句子 499 的上下文词: ['of', 'the']
# 句子 500 的上下文词: ['cause', 'heart']
# 句子 501 的上下文词: ['of']
# 句子 502 的上下文词: ['of']
# 句子 503 的上下文词: ['featuring', 'famous']
# 句子 504 的上下文词: ['sponsored', 'by', 'the', 'water']
# 句子 505 的上下文词: ['of', 'circus']
# 句子 506 的上下文词: ['from', 'the', 'mind', 'of', 'a', 'genetically', '-', 'engineered']
# 句子 507 的上下文词: ['are', 'used', 'by']
# 句子 508 的上下文词: [',', 'colorants', 'and', 'chemicals', 'that', 'cause', 'dryness', ',', 'rashes', ',']
# 句子 509 的上下文词: []
# 句子 510 的上下文词: ['has', 'now', 'been', 'dragged', 'into', 'the', 'whole', 'revolting']
# 句子 511 的上下文词: []
# 句子 512 的上下文词: ['of']
# 句子 513 的上下文词: ['was', 'sent', 'to', 'an', 'HTTPS']
# 句子 514 的上下文词: [',', 'in', 'her', 'first', 'holiday', 'season', 'as', 'an', 'Elm', 'Creek', 'Quilter', ',', 'creates', 'a']
# 句子 515 的上下文词: []
# 句子 516 的上下文词: ['used', 'during', 'one', 'of', 'the', 'performances', 'caused', 'a']
# 句子 517 的上下文词: ['and', 'stress', 'triggers', 'acne']
# 句子 518 的上下文词: ['that', 'has', 'been', 'caused', 'by', 'the']
# 句子 519 的上下文词: ["'s"]
# 句子 520 的上下文词: ['used', 'by', 'a', 'beginning']
# 句子 521 的上下文词: ['was', 'in', 'a']
# 句子 522 的上下文词: ['of', 'the']
# 句子 523 的上下文词: ['of']
# 句子 524 的上下文词: ['was', 'put', 'inside', 'the', 'glass']
# 句子 525 的上下文词: ['the', 'land', 'with', 'a', 'single', 'furrow']
# 句子 526 的上下文词: ['by']
# 句子 527 的上下文词: ['was', 'in', 'a']
# 句子 528 的上下文词: ['of', 'the', 'intestines', 'caused', 'by', 'one', 'of', 'several']
# 句子 529 的上下文词: ['and', 'shellfish', 'have', 'migrated', 'to', 'cooler']
# 句子 530 的上下文词: ['into', 'the']
# 句子 531 的上下文词: ['of', 'this']
# 句子 532 的上下文词: ['is', 'comprised', 'of', 'a']
# 句子 533 的上下文词: ['of']
# 句子 534 的上下文词: ['got', 'put', 'up', 'by', 'these']
# 句子 535 的上下文词: []
# 句子 536 的上下文词: ['and', 'meat', 'cause', 'heart', 'disease', 'and']
# 句子 537 的上下文词: ['after', 'the']
# 句子 538 的上下文词: ['were', 'misplaced', 'into', 'alternative']
# 句子 539 的上下文词: ['of']
# 句子 540 的上下文词: []
# 句子 541 的上下文词: ['assessed', 'the', 'reliability', 'of', 'the', 'basic', 'diagnostic', 'methods', 'in']
# 句子 542 的上下文词: ['represents', 'the', 'last']
# 句子 543 的上下文词: ['of', 'a']
# 句子 544 的上下文词: []
# 句子 545 的上下文词: ['is', 'still', 'one', 'of', 'the', 'leading', 'causes', 'of', 'maternal']
# 句子 546 的上下文词: ['made', 'from', 'an', 'assembly', 'of']
# 句子 547 的上下文词: ['barefoot', ',', 'running', 'in', 'conventional', 'running']
# 句子 548 的上下文词: ['of', 'corn', 'tortillas', ',', 'which', 'was', 'inside', 'a']
# 句子 549 的上下文词: ['made', 'by', 'the', 'Graff', 'jewellery']
# 句子 550 的上下文词: []
# 句子 551 的上下文词: ['was', 'the', 'cause', 'of']
# 句子 552 的上下文词: ['arrived', 'to', 'the']
# 句子 553 的上下文词: ['that', 'killed', 'a', 'visitor', 'escaped', 'from', 'its', 'high', '-', 'walled']
# 句子 554 的上下文词: ['was', 'hidden', 'in', 'an']
# 句子 555 的上下文词: ['has', 'two', 'heating']
# 句子 556 的上下文词: ['of', 'the']
# 句子 557 的上下文词: ['are', 'moving', 'into', 'big']
# 句子 558 的上下文词: []
# 句子 559 的上下文词: ['resulted', 'in', '256', 'deaths', 'and', '3,402']
# 句子 560 的上下文词: ['on', 'the', 'security']
# 句子 561 的上下文词: ['piled', 'up', 'the', 'dirt', 'into', 'a', 'small']
# 句子 562 的上下文词: ['was', 'inside', 'a']
# 句子 563 的上下文词: ['into', 'the', 'author', "'s"]
# 句子 564 的上下文词: ['of']
# 句子 565 的上下文词: ['of', 'fellow']
# 句子 566 的上下文词: ['of', 'the']
# 句子 567 的上下文词: ['mixes', 'the', 'Holy', 'Oil', 'and', 'the', 'wine', 'with', 'a']
# 句子 568 的上下文词: ['to', 'a', 'local']
# 句子 569 的上下文词: ['was', 'in', 'a']
# 句子 570 的上下文词: ['in', 'a']
# 句子 571 的上下文词: ['applied', 'to', 'the', 'six']
# 句子 572 的上下文词: ['which', 'is', 'the', 'source', 'of', 'the']
# 句子 573 的上下文词: ['are', 'running', 'into', 'temperature', 'sensitivity']
# 句子 574 的上下文词: ['showing']
# 句子 575 的上下文词: ['is', 'the', 'preferred']
# 句子 576 的上下文词: ['from']
# 句子 577 的上下文词: ['covers', 'the', 'candle', 'with', 'a', 'tall']
# 句子 578 的上下文词: [',', 'substance', 'abuse', 'and', 'poverty', 'all', 'lead', 'to']
# 句子 579 的上下文词: ['caused', 'a']
# 句子 580 的上下文词: ['was', 'focused', 'on']
# 句子 581 的上下文词: ['of']
# 句子 582 的上下文词: ['produced', 'by', 'a']
# 句子 583 的上下文词: ['of', 'various']
# 句子 584 的上下文词: ["'s", 'anti', '-', 'establishment']
# 句子 585 的上下文词: ['have', 'been', 'imported', 'into', 'several']
# 句子 586 的上下文词: ['of', 'French']
# 句子 587 的上下文词: ['has', 'a', 'flat', 'belt']
# 句子 588 的上下文词: ['are', 'familiar', 'with', 'antipsychotic', ',', 'anti', '-', 'anxiety', ',', 'and', 'antidepressant']
# 句子 589 的上下文词: ['have', 'been', 'denoted', 'with', 'an']
# 句子 590 的上下文词: ['code', 'serves', 'to', 'identify', 'the', 'cashier', 'using', 'the', 'electronic', 'cash']
# 句子 591 的上下文词: ['emphasised', 'the']
# 句子 592 的上下文词: ['of', 'a', 'murderer', 'was', 'dangling', 'from', 'the']
# 句子 593 的上下文词: ['causes', 'fluid']
# 句子 594 的上下文词: ['of', 'independent']
# 句子 595 的上下文词: ['has', 'constructed', 'two']
# 句子 596 的上下文词: ['of', 'female']
# 句子 597 的上下文词: ['invented', 'a']
# 句子 598 的上下文词: ['of']
# 句子 599 的上下文词: ['into']
# 句子 600 的上下文词: ['was', 'contained', 'in', 'a', '5', '-', 'mm']
# 句子 601 的上下文词: ['from', 'Allen', "'s"]
# 句子 602 的上下文词: ['that', 'has', 'been', 'caused', 'by', 'the', 'company']
# 句子 603 的上下文词: ['was', 'placed', 'into', 'warm', 'sterile']
# 句子 604 的上下文词: ['are', 'sent', 'to', 'the']
# 句子 605 的上下文词: ['have', 'coated']
# 句子 606 的上下文词: ['was', 'in', 'a']
# 句子 607 的上下文词: ['conquered', 'the', 'fears', 'associated', 'with']
# 句子 608 的上下文词: ['taking', 'a']
# 句子 609 的上下文词: ['treats', 'the', 'patient', 'with', 'a', 'certain', 'kind', 'of', 'manual']
# 句子 610 的上下文词: ['assists', 'separating']
# 句子 611 的上下文词: ['is', 'part', 'of', 'the', 'WHO', 'information']
# 句子 612 的上下文词: ['ran', 'into']
# 句子 613 的上下文词: ['with']
# 句子 614 的上下文词: ['of', 'taxpayer']
# 句子 615 的上下文词: ['that', 'filters', 'the', 'dirt', 'through', 'the']
# 句子 616 的上下文词: ['established', 'a', 'major']
# 句子 617 的上下文词: ['causes', 'exudative']
# 句子 618 的上下文词: ['flew', 'into', 'the']
# 句子 619 的上下文词: ['of', 'the', 'important']
# 句子 620 的上下文词: ['shown', 'in', 'the']
# 句子 621 的上下文词: ['of']
# 句子 622 的上下文词: ['triggered', 'by', 'the', 'Pentagon']
# 句子 623 的上下文词: []
# 句子 624 的上下文词: ['at', 'the', 'UvH', 'comprises', 'scholars', 'in', 'humanistics', ',', 'religious', 'and', 'cultural', 'scholars', ',', 'social', 'scientists', ',']
# 句子 625 的上下文词: ['at', 'the', 'mine', 'has', 'been', 'caused', 'by', 'the']
# 句子 626 的上下文词: ['studies', 'the']
# 句子 627 的上下文词: ['had', 'an', 'important']
# 句子 628 的上下文词: ['knit', 'a', 'giant', 'really', 'thick', 'woolen']
# 句子 629 的上下文词: []
# 句子 630 的上下文词: ['of', 'the', 'climactic', 'battle', 'cue', ',', '"', 'Neodammerung', '"', 'is', 'derived', 'from', 'the', 'German']
# 句子 631 的上下文词: ['with']
# 句子 632 的上下文词: ['is', 'issued', 'from', '28']
# 句子 633 的上下文词: ['has', 'been', 'fitted', 'with', 'a', 'Mirus', 'automatic', 'sheet']
# 句子 634 的上下文词: ['that', 'the', 'Roman']
# 句子 635 的上下文词: ['into', 'his']
# 句子 636 的上下文词: ['of', 'the']
# 句子 637 的上下文词: ['deep', 'inside', 'the']
# 句子 638 的上下文词: ['to', 'our']
# 句子 639 的上下文词: ['of', 'different']
# 句子 640 的上下文词: ['and', 'beverage']
# 句子 641 的上下文词: ['regains', 'the', 'movement', 'roughly', 'equal', 'to', 'walking', 'on', 'solid', 'ground', 'by', 'using']
# 句子 642 的上下文词: ['by', 'the', 'Blazer']
# 句子 643 的上下文词: ['from']
# 句子 644 的上下文词: ['work', 'by', 'using']
# 句子 645 的上下文词: ['has', 'given', 'a', 'provisional']
# 句子 646 的上下文词: ['was', 'enclosed', 'in', 'tight', 'plastic']
# 句子 647 的上下文词: ['allege', 'that', 'his']
# 句子 648 的上下文词: ['had', 'declared', 'some', 'initial']
# 句子 649 的上下文词: ['grows', 'from', 'an']
# 句子 650 的上下文词: ['into', 'randomised', 'controlled']
# 句子 651 的上下文词: ['plays', 'her']
# 句子 652 的上下文词: ['created', 'by', 'the']
# 句子 653 的上下文词: ['covers', 'von', 'Neurath', "'s"]
# 句子 654 的上下文词: ['of']
# 句子 655 的上下文词: ['was', 'folded', 'up', 'accordion', '-', 'style', 'inside', 'a']
# 句子 656 的上下文词: ['to', 'inform', 'about']
# 句子 657 的上下文词: ['caused', 'by', 'the']
# 句子 658 的上下文词: ['then', 'was', 'put', 'into', 'an', 'ounce']
# 句子 659 的上下文词: ['comes', 'from', 'the', 'writer', "'s"]
# 句子 660 的上下文词: []
# 句子 661 的上下文词: ['full', 'of']
# 句子 662 的上下文词: ['was', 'in', 'a']
# 句子 663 的上下文词: ['is', 'to', 'present', 'some', 'recent', 'experimental']
# 句子 664 的上下文词: ['that', 'is', 'centered', 'around', 'a', 'troubled', 'teenage']
# 句子 665 的上下文词: ['caused', 'by', 'the']
# 句子 666 的上下文词: ['evaporated', 'from', 'the']
# 句子 667 的上下文词: ['of', 'stampeding']
# 句子 668 的上下文词: ['use', 'a', 'paste', 'like']
# 句子 669 的上下文词: ['is', 'landing', 'into']
# 句子 670 的上下文词: ['is', 'falling', 'into']
# 句子 671 的上下文词: ['is', 'one', 'of', 'the', 'commonest', 'causes', 'of']
# 句子 672 的上下文词: ['at', 'Chertsey', 'and', 'Abingdon', 'were', 'founded', 'by', 'the']
# 句子 673 的上下文词: []
# 句子 674 的上下文词: ['triggered', 'by', 'the', 'sudden']
# 句子 675 的上下文词: ['have', 'attached', 'the', 'flange', 'with', 'a', 'number', 'of']
# 句子 676 的上下文词: ['of']
# 句子 677 的上下文词: ['came', 'from', 'a', 'Minnesota']
# 句子 678 的上下文词: ['of']
# 句子 679 的上下文词: ['has', 'put', 'up', 'with', 'verbal']
# 句子 680 的上下文词: ['of', 'vampire']
# 句子 681 的上下文词: ['goes', 'into']
# 句子 682 的上下文词: ['of', 'the', 'double', 'stent', 'was', 'placed', 'inside', 'the', 'urinary']
# 句子 683 的上下文词: ["'s", 'output', 'of']
# 句子 684 的上下文词: ['is', 'falling', 'into', 'a']
# 句子 685 的上下文词: ['have', 'approached', 'the', 'colony', "'s"]
# 句子 686 的上下文词: ['caused', 'a', 'chain']
# 句子 687 的上下文词: ['I', 'had', 'was', 'in', 'a']
# 句子 688 的上下文词: ['into']
# 句子 689 的上下文词: [',', 'which', 'has', 'over', '5000', 'members', ',', 'is', 'part', 'of', 'a', 'national']
# 句子 690 的上下文词: ['is', 'postponed', 'to']
# 句子 691 的上下文词: ['into', 'his']
# 句子 692 的上下文词: ['of', 'secondary']
# 句子 693 的上下文词: ['that', 'occur', 'after', 'DTaP', 'are', 'caused', 'by', 'a']
# 句子 694 的上下文词: [',', 'the', 'plugs', 'in', 'the']
# 句子 695 的上下文词: ['governing']
# 句子 696 的上下文词: ['torn', 'from', 'the']
# 句子 697 的上下文词: ['relates']
# 句子 698 的上下文词: []
# 句子 699 的上下文词: ['who', 'fell', 'from', 'a']
# 句子 700 的上下文词: ['is', 'exported', 'to', 'the']
# 句子 701 的上下文词: ['indicating', 'the']
# 句子 702 的上下文词: ['in', 'his']
# 句子 703 的上下文词: ['from', '1301', 'by', 'an', 'Iranian']
# 句子 704 的上下文词: ['after', 'the']
# 句子 705 的上下文词: ['of', 'the']
# 句子 706 的上下文词: ['or', 'smoke', 'cause']
# 句子 707 的上下文词: ['flow', 'into', 'Halifax', 'recreational']
# 句子 708 的上下文词: ['portrays', 'his', 'students', "'", 'term']
# 句子 709 的上下文词: ['is', 'constructed', 'from', 'random']
# 句子 710 的上下文词: [',', 'has', 'carefully', 'devised', 'an', 'amended', 'research']
# 句子 711 的上下文词: ['describing', 'the', 'bakery', "'s"]
# 句子 712 的上下文词: ['under']
# 句子 713 的上下文词: ['illustrates', 'the']
# 句子 714 的上下文词: ['resulted', 'in', 'the']
# 句子 715 的上下文词: ['who', 'started', 'the', 'vaccine', '-', 'autism', 'myth', 'with', 'his']
# 句子 716 的上下文词: ['drafted', 'a', 'great']
# 句子 717 的上下文词: ['have', 'concerned', 'fictional', 'secret']
# 句子 718 的上下文词: ['of', 'giant']
# 句子 719 的上下文词: ['are', 'tension', 'headaches', 'or', 'headaches', 'which', 'are', 'caused', 'by', 'taking', 'too', 'many']
# 句子 720 的上下文词: ['have', 'been', 'moving', 'into', 'more', 'specialised', 'and', 'skill', '-', 'intensive']
# 句子 721 的上下文词: ['lit', 'a']
# 句子 722 的上下文词: ['is', 'transferred', 'directly', 'into', 'a', 'target', 'processor']
# 句子 723 的上下文词: [',', 'which', 'he', 'deposited', 'proudly', 'in', 'a']
# 句子 724 的上下文词: ['of', 'snowy']
# 句子 725 的上下文词: ['of', 'slum']
# 句子 726 的上下文词: ['have', 'been', 'donated', 'to', 'the']
# 句子 727 的上下文词: ['has', 'made', 'a']
# 句子 728 的上下文词: ['of', 'the']
# 句子 729 的上下文词: ['are', 'eluded', 'from', 'the', 'fundamental']
# 句子 730 的上下文词: ['of', 'white']
# 句子 731 的上下文词: ['took', 'off', 'from', 'the']
# 句子 732 的上下文词: ['marked', 'their', 'wares', 'with', 'ink']
# 句子 733 的上下文词: ['with', 'an']
# 句子 734 的上下文词: ['of', 'Haematopinus']
# 句子 735 的上下文词: ['have', 'been', 'secretly', 'thrown', 'into', 'the']
# 句子 736 的上下文词: ['is', 'caused', 'by', 'pneumococcus']
# 句子 737 的上下文词: ['is', 'promoting', 'the']
# 句子 738 的上下文词: ['of', 'aged']
# 句子 739 的上下文词: ['criticizes', 'the', 'institutionalized', 'nuclear']
# 句子 740 的上下文词: ['applying', 'to']
# 句子 741 的上下文词: ['into']
# 句子 742 的上下文词: ['of']
# 句子 743 的上下文词: ['depicts', 'the', 'harsh']
# 句子 744 的上下文词: ['of', 'Chicago']
# 句子 745 的上下文词: ['was', 'landing', 'into', 'the', 'high']
# 句子 746 的上下文词: ['caused', 'by', 'the']
# 句子 747 的上下文词: ['of']
# 句子 748 的上下文词: ['is', 'placed', 'into', 'the']
# 句子 749 的上下文词: ['define', 'the', 'contemporary', 'terrorist']
# 句子 750 的上下文词: ['is', 'added', 'into']
# 句子 751 的上下文词: ['moved', 'into', 'the', 'floating']
# 句子 752 的上下文词: ['arrives', 'from', 'the', 'upper']
# 句子 753 的上下文词: ['contained', 'a']
# 句子 754 的上下文词: ['into', 'developing']
# 句子 755 的上下文词: ['threw', 'together', 'a']
# 句子 756 的上下文词: ['now', 'seen', 'in', 'the', 'endometrium', 'are', 'caused', 'by', 'a']
# 句子 757 的上下文词: ['to', 'the']
# 句子 758 的上下文词: [',', 'a', 'mixture', 'of', 'gasoline', ',', 'water', 'and', 'caustic', 'soda', ',', 'gave', 'off', 'toxic']
# 句子 759 的上下文词: ['were', 'thrown', 'into', 'the']
# 句子 760 的上下文词: []
# 句子 761 的上下文词: ['with']
# 句子 762 的上下文词: ['of', 'twelve']
# 句子 763 的上下文词: ['started', 'from', 'the', 'same']
# 句子 764 的上下文词: ['on', 'the']
# 句子 765 的上下文词: ['run', 'the', 'gamut', 'of']
# 句子 766 的上下文词: ['as', 'having', 'been', 'built', 'as', 'a', 'store', 'house', 'by', 'the', 'Imlay', 'brothers', ',', 'early', 'European']
# 句子 767 的上下文词: ['into', 'the', 'fermenting']
# 句子 768 的上下文词: [',', 'some', 'of', 'them', 'book', 'long', ',', 'have', 'made', 'a', 'notable', 'contribution', 'to', 'scientific']
# 句子 769 的上下文词: ['of', 'the']
# 句子 770 的上下文词: ['into', 'a', 'separate', 'state', '-', 'specific']
# 句子 771 的上下文词: ['of', 'theodicy', 'is', 'from', 'an', 'academical']
# 句子 772 的上下文词: ['are', 'caused', 'by']
# 句子 773 的上下文词: ['for', 'and', 'against', 'the']
# 句子 774 的上下文词: [',', 'he', 'talked', 'about', 'his']
# 句子 775 的上下文词: ['into']
# 句子 776 的上下文词: ['that', 'resulted', 'in', 'several']
# 句子 777 的上下文词: ['authored', 'by', 'an', 'obscure', 'Danish']
# 句子 778 的上下文词: ['of']
# 句子 779 的上下文词: ['during', 'this', 'period', 'tended', 'to', 'feature', 'the']
# 句子 780 的上下文词: ['reported', 'extensively', 'and', 'vividly', 'on', 'the']
# 句子 781 的上下文词: ['is', 'used', 'to', 'indicate', 'the']
# 句子 782 的上下文词: ['telling', 'of', 'his']
# 句子 783 的上下文词: ['Josie', 'speaks', 'about', 'her']
# 句子 784 的上下文词: ['into', 'this']
# 句子 785 的上下文词: ['was', 'placed', 'inside', 'the', 'sterile']
# 句子 786 的上下文词: ['on', 'the', 'upper', 'right']
# 句子 787 的上下文词: ['was', 'misplaced', 'into', 'the', 'wrong']
# 句子 788 的上下文词: ['were', 'sent', 'to', '144']
# 句子 789 的上下文词: ['has', '3', 'beautifully', 'decorated']
# 句子 790 的上下文词: ['was', 'comprised', 'of', 'the', 'county']
# 句子 791 的上下文词: ['in', 'a']
# 句子 792 的上下文词: ['who', 'did', 'the']
# 句子 793 的上下文词: ['is', 'a', 'special', 'kind', 'of', 'discourse', 'that', 'uses']
# 句子 794 的上下文词: ['have', 'been', 'injected', 'into', 'the', 'vitreous']
# 句子 795 的上下文词: ['were', 'thrown', 'into', 'the']
# 句子 796 的上下文词: ['has', 'moved', 'into', 'the', '21st']
# 句子 797 的上下文词: ['were', 'pointed', 'out', 'during', 'the']
# 句子 798 的上下文词: ['were', 'in', 'a']
# 句子 799 的上下文词: ['attaches', 'a', 'socket']
# 句子 800 的上下文词: ['of', 'high', '-', 'profile', 'master']
# 句子 801 的上下文词: ['were', 'draining', 'into']
# 句子 802 的上下文词: ['caused', 'a']
# 句子 803 的上下文词: ['moved', 'into', 'a', 'medical']
# 句子 804 的上下文词: ['in', 'a']
# 句子 805 的上下文词: ['later', 'in', 'the']
# 句子 806 的上下文词: ['has', 'come', 'from']
# 句子 807 的上下文词: ['make']
# 句子 808 的上下文词: ['comprises', 'a', 'stapling', 'head', '(', '2', ')', 'and', 'an']
# 句子 809 的上下文词: ['is', 'generated', 'by', 'an', 'externally', 'modulated', 'tunable']
# 句子 810 的上下文词: ['was', 'caused', 'by', 'the']
# 句子 811 的上下文词: ['caused', 'by', 'bond']
# 句子 812 的上下文词: ['into', 'the']
# 句子 813 的上下文词: ['to', 'your', 'new']
# 句子 814 的上下文词: ['has', 'the', 'tallest']
# 句子 815 的上下文词: ['to', 'the', 'local']
# 句子 816 的上下文词: ['piling', 'sidewall']
# 句子 817 的上下文词: ['after', 'the', 'fire']
# 句子 818 的上下文词: ['was', 'enclosed', 'in', 'a']
# 句子 819 的上下文词: []
# 句子 820 的上下文词: ['was', 'the', 'best', 'part', 'of', 'the']
# 句子 821 的上下文词: ['of', 'the']
# 句子 822 的上下文词: ['which', 'was', 'locked', 'in', 'a']
# 句子 823 的上下文词: ['works', 'with', 'a', 'hot', 'water', 'storage']
# 句子 824 的上下文词: ['is', 'that']
# 句子 825 的上下文词: ['triggered', 'by', 'the', 'massive']
# 句子 826 的上下文词: ['with', 'all']
# 句子 827 的上下文词: ['written', 'by', 'a', 'American']
# 句子 828 的上下文词: ['that', 'has', 'been', 'caused', 'by', 'the']
# 句子 829 的上下文词: ['was', 'in', 'a']
# 句子 830 的上下文词: ['was', 'in', 'a']
# 句子 831 的上下文词: ['consists', 'of', 'few']
# 句子 832 的上下文词: ['is', 'narrated', 'through']
# 句子 833 的上下文词: ['in', 'a', 'serving']
# 句子 834 的上下文词: ['of', 'three']
# 句子 835 的上下文词: ['was', 'placed', 'inside', 'a']
# 句子 836 的上下文词: ['set', 'in', 'a', 'psychiatric', 'unit', 'has', 'been', 'criticised', 'by', 'a', 'TV']
# 句子 837 的上下文词: ['is', 'one', 'of', 'the', 'main', 'causes', 'of']
# 句子 838 的上下文词: ['regulate', 'the', 'voltage', 'using', 'a', 'shunt']
# 句子 839 的上下文词: ['of', 'my']
# 句子 840 的上下文词: ['is', 'found', 'in', 'the', 'second']
# 句子 841 的上下文词: ['of']
# 句子 842 的上下文词: ['were', 'in', 'a']
# 句子 843 的上下文词: ['watched', 'the', 'snow', 'through', 'the']
# 句子 844 的上下文词: ['of', 'Muslim']
# 句子 845 的上下文词: ['which', 'took', 'the']
# 句子 846 的上下文词: ['had', 'left', 'the']
# 句子 847 的上下文词: ['to', 'the', 'historical', 'documentary']
# 句子 848 的上下文词: ['of']
# 句子 849 的上下文词: ['is', 'a', 'participant', 'in', 'the']
# 句子 850 的上下文词: ['have', 'often', 'been', 'featured', 'in']
# 句子 851 的上下文词: ['started', 'at', 'the', 'rest']
# 句子 852 的上下文词: ['raised', 'about']
# 句子 853 的上下文词: ['was', 'passed', 'on', 'to', 'the', 'QObject']
# 句子 854 的上下文词: ['is', 'long', 'and', 'thin', 'with', 'a', 'blue', 'central', 'tail']
# 句子 855 的上下文词: ['basically', 'sails', 'from', 'the', 'harbour', 'to', 'an', 'area', 'of', 'a']
# 句子 856 的上下文词: ['of', 'autism', 'is', 'the', 'topic', 'of']
# 句子 857 的上下文词: ['of', 'goodies', 'was', 'delivered', 'from', 'the']
# 句子 858 的上下文词: ['causing', 'recreational', 'water']
# 句子 859 的上下文词: ['stitching', '600']
# 句子 860 的上下文词: ['into', 'the', 'national']
# 句子 861 的上下文词: ['machined', 'the', 'part', 'with', 'a', '1.25', 'inch']
# 句子 862 的上下文词: ['for', 'the', 'containers', 'in', 'a', 'shallow']
# 句子 863 的上下文词: ['into', 'education']
# 句子 864 的上下文词: ["'s"]
# 句子 865 的上下文词: ['is', 'rooted', 'in', 'an', 'editorial']
# 句子 866 的上下文词: ['with', 'hidden']
# 句子 867 的上下文词: ['was', 'put', 'inside', 'a']
# 句子 868 的上下文词: ['with', 'low']
# 句子 869 的上下文词: ['which', 'applies', 'the']
# 句子 870 的上下文词: ['has', 'a', 'meat']
# 句子 871 的上下文词: ['is', 'distilled', 'from', 'fermented', 'sugarcane']
# 句子 872 的上下文词: ['from', 'my']
# 句子 873 的上下文词: ['of', 'the']
# 句子 874 的上下文词: ['of', '100']
# 句子 875 的上下文词: []
# 句子 876 的上下文词: ['in']
# 句子 877 的上下文词: ['has', 'been', 'caused', 'by', 'a', 'sensitivity', 'reaction', 'in', 'the', 'brain', 'to', 'an', 'ingested']
# 句子 878 的上下文词: [',', 'which', 'was', 'triggered', 'by', 'an', 'exceptionally', 'heavy']
# 句子 879 的上下文词: ['are', 'familiar', 'with', 'the', 'usual', 'weight', 'loss']
# 句子 880 的上下文词: ['into', 'the']
# 句子 881 的上下文词: ['development', 'and', 'support', ',', 'Student', 'Services', 'are', 'also', 'the', 'contact', 'point', 'for', 'other', 'functions', 'such', 'as', 'student', 'out', '-', 'of', '-', 'class', 'involvement', ',', 'student', 'participation', 'in', 'the', 'university']
# 句子 882 的上下文词: ['outlined', 'urgent']
# 句子 883 的上下文词: ['took', 'off', 'from', 'the']
# 句子 884 的上下文词: ['is', 'rooted', 'in', 'the']
# 句子 885 的上下文词: ['is', 'a', 'relatively', 'small', 'constitute', 'part', 'of', 'the', 'Earth', "'s"]
# 句子 886 的上下文词: ['that', 'are', 'used', 'by', 'mortgage']
# 句子 887 的上下文词: ['swore', 'an']
# 句子 888 的上下文词: ['was', 'stored', 'in', 'a', 'wine']
# 句子 889 的上下文词: ['of', 'passengers', 'and', 'crew', ',', 'handed', 'to', 'the', 'purser', 'just', 'before', 'the', 'steamer', 'left', 'Providence', ',', 'was', 'locked', 'in', 'a']
# 句子 890 的上下文词: ['is', 'advertised', 'by', 'the', 'official', 'municipal']
# 句子 891 的上下文词: ['in', 'the']
# 句子 892 的上下文词: ['of']
# 句子 893 的上下文词: ['was', 'coming', 'from', 'a', 'welding']
# 句子 894 的上下文词: ['has', 'been', 'carried', 'out', 'according', 'to', 'the', 'pertinent']
# 句子 895 的上下文词: ['still', 'uses', 'concrete']
# 句子 896 的上下文词: ['gives', 'a', 'summary', 'of', 'holiday']
# 句子 897 的上下文词: ['caused', 'a']
# 句子 898 的上下文词: ['is', 'used', 'for']
# 句子 899 的上下文词: ['into', 'a', 'date', '-', 'based']
# 句子 900 的上下文词: ['hailed', 'from', 'Tezpur']
# 句子 901 的上下文词: ['full', 'of', 'pulled']
# 句子 902 的上下文词: ['are', 'locked', 'in', 'my']
# 句子 903 的上下文词: ['has', 'enrolled', 'in', 'the']
# 句子 904 的上下文词: ['was', 'coming', 'from', 'his', 'own']
# 句子 905 的上下文词: ['in', 'a']
# 句子 906 的上下文词: []
# 句子 907 的上下文词: ['were', 'released', 'into', 'the']
# 句子 908 的上下文词: ['retracts', 'into', 'a']
# 句子 909 的上下文词: ['of']
# 句子 910 的上下文词: ['to']
# 句子 911 的上下文词: ['has', 'proved', 'that', 'the']
# 句子 912 的上下文词: ['caused', 'the']
# 句子 913 的上下文词: ['very', 'probably', 'opened', 'the']
# 句子 914 的上下文词: ['have', 'increasingly', 'been', 'moving', 'into', 'the']
# 句子 915 的上下文词: ['travelled', 'to', 'the']
# 句子 916 的上下文词: ['has', 'been', 'added', 'into', 'the']
# 句子 917 的上下文词: ['was', 'caused', 'by', 'the']
# 句子 918 的上下文词: ['of']
# 句子 919 的上下文词: ['works', 'with', 'a', 'single', 'cup', 'of']
# 句子 920 的上下文词: ['starts', 'at', 'a', 'rather', 'low']
# 句子 921 的上下文词: ['briefly', 'comprises', 'of']
# 句子 922 的上下文词: ['made', 'famous', 'by', 'her', 'lascivious']
# 句子 923 的上下文词: []
# 句子 924 的上下文词: ['of', 'the']
# 句子 925 的上下文词: ['of', 'Scythian', 'horse']
# 句子 926 的上下文词: ['was', 'inside', 'a']
# 句子 927 的上下文词: ['of', 'race']
# 句子 928 的上下文词: ['in', 'India', 'have', 'been', 'added', 'to', 'our']
# 句子 929 的上下文词: ['was', 'a', 'part', 'of', 'the', 'Danish']
# 句子 930 的上下文词: ['from', 'the', 'upstream']
# 句子 931 的上下文词: []
# 句子 932 的上下文词: ['around']
# 句子 933 的上下文词: ['of', 'the']
# 句子 934 的上下文词: ['of', 'Brownville', 'and', 'Fontanelle', 'were', 'founded', 'that']
# 句子 935 的上下文词: ['was', 'already', 'placed', 'in', 'a']
# 句子 936 的上下文词: ['made', 'by', 'a', 'road']
# 句子 937 的上下文词: ['killed', 'him', 'with', 'the']
# 句子 938 的上下文词: ['of', 'the']
# 句子 939 的上下文词: ['creates', 'dishes', 'using', 'farm', 'fresh']
# 句子 940 的上下文词: ['for']
# 句子 941 的上下文词: ['advertises', 'the', '1898']
# 句子 942 的上下文词: ['was', 'distilled', 'from', 'a']
# 句子 943 的上下文词: ['documents', 'children', "'s"]
# 句子 944 的上下文词: ['full', 'of']
# 句子 945 的上下文词: ['of', 'the', 'felt', 'was', 'enclosed', 'in', 'a', 'separate', 'glass']
# 句子 946 的上下文词: ['wrote', 'this']
# 句子 947 的上下文词: ['after', 'brilliant', 'hit', 'song', 'from', 'the', 'fertile', 'imaginations', 'of', 'the', 'great', 'Brill', 'Building']
# 句子 948 的上下文词: ['of']
# 句子 949 的上下文词: []
# 句子 950 的上下文词: ['arrived', 'at', 'the', 'usual']
# 句子 951 的上下文词: []
# 句子 952 的上下文词: ['built', 'on', 'a']
# 句子 953 的上下文词: ['of', 'militia']
# 句子 954 的上下文词: ['runs', 'away', 'from', 'the']
# 句子 955 的上下文词: ['from']
# 句子 956 的上下文词: ['of', 'prominent']
# 句子 957 的上下文词: ['of', 'cholinesterase']
# 句子 958 的上下文词: ['grows', 'from', 'the', 'Southern', 'California', 'desert']
# 句子 959 的上下文词: ['ensued', 'from', 'the']
# 句子 960 的上下文词: ['contained', 'not', 'only', 'recipes', 'but', 'also', 'such', 'things', 'as']
# 句子 961 的上下文词: ['into']
# 句子 962 的上下文词: ['put', 'into', 'a']
# 句子 963 的上下文词: ['was', 'triggered', 'by', 'the', 'growing', 'use', 'of', 'reading', 'and']
# 句子 964 的上下文词: ['describes', 'the']
# 句子 965 的上下文词: ['contains', 'the', 'witness', "'s", 'factual']
# 句子 966 的上下文词: ['of', 'the']
# 句子 967 的上下文词: ['into']
# 句子 968 的上下文词: ['was', 'investigating']
# 句子 969 的上下文词: ['grows', 'from', 'the']
# 句子 970 的上下文词: ['caused', 'by', 'a', 'heavy', 'goods']
# 句子 971 的上下文词: ['was', 'from', 'an', 'old', '-', 'line', 'investment', 'counsel', '-', 'mutual', 'fund']
# 句子 972 的上下文词: ['has', 'been', 'added', 'to', 'the']
# 句子 973 的上下文词: ['of', 'Wolf', "'s"]
# 句子 974 的上下文词: ['of', 'the']
# 句子 975 的上下文词: [',', 'one', 'meter', 'on', 'each', 'side', ',', 'is', 'enclosed', 'in', 'a', 'thermally', 'insulating']
# 句子 976 的上下文词: ['or', 'spikes', 'are', 'caused', 'by']
# 句子 977 的上下文词: ['an']
# 句子 978 的上下文词: ['caused', 'by', 'the']
# 句子 979 的上下文词: ['are', 'caused', 'by', 'a', 'homogeneous', 'group', 'of', 'keratinophilic']
# 句子 980 的上下文词: ['triggered', 'by', 'the']
# 句子 981 的上下文词: ['converts', 'sound', 'into', 'an', 'electrical']
# 句子 982 的上下文词: ['takes', 'part', 'in', 'the']
# 句子 983 的上下文词: ['produced', 'an']
# 句子 984 的上下文词: ['into']
# 句子 985 的上下文词: ['into', 'three']
# 句子 986 的上下文词: ['was', 'manufactured', 'in', 'the']
# 句子 987 的上下文词: ['of', 'eirie']
# 句子 988 的上下文词: ['use', 'a', 'pair', 'of', 'large', 'chin']
# 句子 989 的上下文词: ['into', 'the']
# 句子 990 的上下文词: ['into', 'the']
# 句子 991 的上下文词: ['in', 'the']
# 句子 992 的上下文词: ['have', 'moved', 'into', 'my']
# 句子 993 的上下文词: []
# 句子 994 的上下文词: ['on', 'the']
# ...
# 句子 1659 的上下文向量:
#  [-0.01315459  0.0581944   0.0106459   0.02379918 -0.00961657 -0.06855949
#   0.03300939  0.10966873 -0.0588414  -0.06458467  0.00772053 -0.08433145
#  -0.01135331  0.01233312  0.02972401 -0.04269019  0.03788748 -0.00293343
#  -0.03679525 -0.13156107  0.01737205  0.01278394  0.03565325 -0.01705301
#  -0.02488117  0.01476575 -0.0313569   0.006238   -0.03861116  0.01500543
#   0.03016541 -0.01511926  0.04145046 -0.0675824  -0.02100543  0.04519996
#   0.02111445  0.01786135 -0.02301166 -0.04544275  0.02255236 -0.05301619
#  -0.0219977   0.01623479  0.0499234  -0.04247439 -0.06831465 -0.02283681
#   0.03022708  0.04534955  0.00391899 -0.04378157 -0.019848   -0.02271792
#  -0.02257783  0.01811013  0.03335299 -0.01726945 -0.01296838  0.00809136
#   0.02490828 -0.01143016  0.05363964  0.01518921 -0.0532977   0.08216756
#   0.02340934  0.06391402 -0.06532722  0.03423173  0.02738978  0.04913342
#   0.05024881  0.006935    0.04743514  0.03151956  0.0476381   0.01689382
#  -0.00977725 -0.00810983 -0.05040678 -0.02020377 -0.02205895  0.03988207
#  -0.01366708 -0.01950713  0.02228638  0.0171136   0.04030906  0.00173799
#   0.05944571  0.02843006  0.03912867  0.01996854  0.08770235  0.02264338
#  -0.00676841 -0.02894762 -0.00775606 -0.0038402 ]
# 句子 1660 的上下文向量:
#  [-0.04282381  0.21453829  0.03948194  0.08804391 -0.03478223 -0.25303394
#   0.13443497  0.42920136 -0.22451949 -0.250987    0.02989965 -0.32201338
#  -0.05182765  0.04697305  0.10334392 -0.15206239  0.14666255 -0.00643986
#  -0.1428639  -0.49800012  0.07319225  0.05029107  0.13507359 -0.07390466
#  -0.08531041  0.05583858 -0.11829474  0.01249795 -0.1533212   0.04992413
#   0.11081786 -0.05003111  0.15282431 -0.25950405 -0.07232264  0.17198052
#   0.0856344   0.06167302 -0.08190827 -0.17155926  0.07796373 -0.20295995
#  -0.08732633  0.0551749   0.20186086 -0.15831225 -0.26824257 -0.07492261
#   0.10617861  0.1670424   0.01330685 -0.1633962  -0.07066305 -0.08640097
#  -0.07866341  0.06694877  0.12253737 -0.0843503  -0.03946715  0.02899898
#   0.08906294 -0.04016438  0.20364495  0.0546419  -0.19270979  0.30991822
#   0.0955224   0.24494097 -0.23623677  0.12592237  0.10602292  0.1690086
#   0.18188944  0.02255394  0.17244628  0.12867029  0.18679708  0.0588681
#  -0.03343899 -0.02860566 -0.1896939  -0.06809776 -0.08822444  0.15071091
#  -0.05299305 -0.08328631  0.10310462  0.06665832  0.14292856  0.00781179
#   0.23425105  0.10574882  0.14752576  0.06831314  0.33253565  0.09528296
#  -0.02096292 -0.11437543 -0.02017628 -0.01878708]
# 句子 1661 的上下文向量:
#  [-7.46276528e-02  3.69500935e-01  7.21224025e-02  1.54524416e-01
#  -5.21631576e-02 -4.31300193e-01  2.34785318e-01  7.27841914e-01
#  -3.90114933e-01 -4.32174146e-01  5.51308282e-02 -5.57010829e-01
#  -8.43519941e-02  8.08343366e-02  1.74257308e-01 -2.54837930e-01
#   2.57599175e-01 -4.09523607e-04 -2.39893734e-01 -8.57829690e-01
#   1.23500749e-01  8.42151046e-02  2.26835102e-01 -1.25114799e-01
#  -1.42433345e-01  9.81710255e-02 -1.99223995e-01  3.13529372e-02
#  -2.68768966e-01  9.23236161e-02  1.99524641e-01 -9.48100463e-02
#   2.67460525e-01 -4.44037616e-01 -1.23356387e-01  2.97689795e-01
#   1.56393021e-01  1.11089624e-01 -1.27710685e-01 -2.90142477e-01
#   1.39105439e-01 -3.49145889e-01 -1.56863719e-01  9.62823778e-02
#   3.37023556e-01 -2.73693562e-01 -4.55915064e-01 -1.26746923e-01
#   1.82284430e-01  2.82441825e-01  1.78699940e-02 -2.81870991e-01
#  -1.19447052e-01 -1.43297464e-01 -1.34576648e-01  1.23312443e-01
#   2.16445968e-01 -1.35303706e-01 -6.65376633e-02  5.27348816e-02
#   1.44692466e-01 -6.45763949e-02  3.41077983e-01  9.59140882e-02
#  -3.36762518e-01  5.32045722e-01  1.64492965e-01  4.12176192e-01
#  -4.00251269e-01  2.15343252e-01  1.77970186e-01  2.93329597e-01
#   3.15845847e-01  4.28627729e-02  3.00965071e-01  2.13811129e-01
#   3.10826480e-01  1.01308197e-01 -6.21358901e-02 -5.01249805e-02
#  -3.28027964e-01 -1.18010044e-01 -1.41301140e-01  2.61766911e-01
#  -9.53130648e-02 -1.37655348e-01  1.70834541e-01  1.03756309e-01
#   2.52767086e-01  6.61414023e-03  3.95158291e-01  1.85828492e-01
#   2.60592550e-01  1.21146649e-01  5.63267708e-01  1.58493161e-01
#  -3.32531966e-02 -1.98268414e-01 -3.08479853e-02 -2.65429616e-02]
# 句子 1662 的上下文向量:
#  [-0.04926325  0.24725667  0.04347082  0.09843317 -0.03387856 -0.28280225
#   0.15683597  0.47777537 -0.25577903 -0.28269714  0.03584769 -0.37146455
#  -0.05591917  0.04866281  0.11272778 -0.1770735   0.16839509 -0.00783497
#  -0.1591993  -0.56236994  0.07348742  0.05938558  0.14966892 -0.07478762
#  -0.10208718  0.06002422 -0.13345681  0.01409738 -0.17784497  0.06029301
#   0.13632154 -0.06697513  0.17099243 -0.2958118  -0.08498576  0.19687283
#   0.10102926  0.07982109 -0.08234638 -0.19643617  0.09280573 -0.23390833
#  -0.10491165  0.06200142  0.22110656 -0.18271613 -0.3047623  -0.08382307
#   0.11959434  0.18479306  0.01140473 -0.19115663 -0.07400186 -0.09628567
#  -0.09170078  0.08197738  0.14607602 -0.09097309 -0.04751978  0.03040909
#   0.09868193 -0.04865711  0.23138173  0.06300115 -0.22367486  0.35011202
#   0.10276271  0.27424783 -0.27020726  0.13695851  0.11822939  0.19952954
#   0.21255623  0.02714174  0.1973269   0.14359954  0.19966021  0.06882721
#  -0.04191957 -0.03137358 -0.21435252 -0.08328123 -0.09163834  0.17182815
#  -0.05933933 -0.09634741  0.10677283  0.07684304  0.17092386  0.00464082
#   0.26581508  0.12586069  0.16861074  0.07680095  0.376065    0.10714406
#  -0.02015242 -0.12950125 -0.02126885 -0.02295758]
# 句子 1663 的上下文向量:
#  [-0.02247483  0.1119949   0.01866131  0.04595087 -0.01421959 -0.12792832
#   0.06832882  0.21273203 -0.11251643 -0.12545311  0.01671031 -0.162925
#  -0.02188726  0.02052166  0.05298595 -0.07409307  0.07277498 -0.00163945
#  -0.06956127 -0.24827428  0.03380287  0.02427902  0.06630003 -0.03144674
#  -0.0449136   0.02817867 -0.0576186   0.0053047  -0.0780908   0.02577522
#   0.05727604 -0.02625749  0.07344665 -0.13282116 -0.03808076  0.09092769
#   0.04486211  0.03575038 -0.03725976 -0.08633938  0.04247007 -0.10159949
#  -0.04768649  0.02657732  0.09642819 -0.0801075  -0.13219598 -0.03761627
#   0.05069177  0.08166745  0.00609484 -0.08340305 -0.03653921 -0.04078164
#  -0.04064786  0.03780792  0.06453097 -0.04341656 -0.02253608  0.0141253
#   0.04073204 -0.01828512  0.10029894  0.03101658 -0.09426674  0.15854137
#   0.04649173  0.12304375 -0.11796675  0.06281876  0.04912642  0.08759478
#   0.0920057   0.01385939  0.08762074  0.06565847  0.08633646  0.03060903
#  -0.01975464 -0.01090599 -0.09637115 -0.03341162 -0.03858266  0.07273384
#  -0.02823623 -0.03902095  0.04805538  0.03268379  0.07466099  0.00395333
#   0.11921071  0.05762013  0.06920121  0.03866778  0.16716309  0.04551923
#  -0.01184824 -0.05970961 -0.00615657 -0.0091231 ]
# 句子 1664 的上下文向量:
#  [-0.0127825   0.06400471  0.01025698  0.02749648 -0.00433064 -0.08066255
#   0.03907175  0.12542449 -0.06861192 -0.07857153  0.00727577 -0.09655484
#  -0.01065955  0.01289399  0.03310164 -0.04751408  0.0446304  -0.0004957
#  -0.04541995 -0.15236142  0.02366429  0.01745537  0.04341748 -0.02779263
#  -0.0283772   0.01407028 -0.03209231  0.00997312 -0.04547715  0.01300687
#   0.03610207 -0.020836    0.04960946 -0.082316   -0.01766612  0.05298669
#   0.0257837   0.02061848 -0.02281951 -0.05433667  0.02314514 -0.06728585
#  -0.02585129  0.01614528  0.06246747 -0.04657802 -0.0790809  -0.02274523
#   0.02802799  0.04510228  0.00460036 -0.05204959 -0.02079963 -0.02048621
#  -0.02146742  0.02630105  0.0389387  -0.02232401 -0.01266921  0.01117228
#   0.02392377 -0.01291784  0.05719309  0.01258689 -0.06256147  0.09423365
#   0.03156977  0.06947488 -0.07451138  0.04021688  0.02920027  0.04821581
#   0.05359004  0.01187567  0.05595748  0.03424605  0.05478617  0.01599767
#  -0.01398295 -0.00990747 -0.06163158 -0.01799189 -0.02851857  0.0477583
#  -0.0185353  -0.02256801  0.03099695  0.0224473   0.04806385 -0.00154335
#   0.07482897  0.03617553  0.04441153  0.02436742  0.09533174  0.02540973
#  -0.00834378 -0.03252186 -0.0095918  -0.007451  ]
# 句子 1665 的上下文向量:
#  [-0.01609836  0.07941873  0.01458217  0.03424139 -0.01261885 -0.09065334
#   0.05397399  0.15406509 -0.08395129 -0.09148364  0.01031474 -0.12185618
#  -0.018824    0.01315312  0.04028085 -0.05755014  0.05215294 -0.00325024
#  -0.05340894 -0.18482411  0.0248428   0.02073863  0.0485067  -0.02602908
#  -0.03140778  0.01929509 -0.04448446  0.00409647 -0.05788951  0.01912409
#   0.0433162  -0.02111906  0.05663346 -0.09585662 -0.02811322  0.06730352
#   0.0335601   0.02657444 -0.02741149 -0.06497391  0.03215173 -0.07584213
#  -0.03072575  0.02070928  0.07347322 -0.05779795 -0.0982492  -0.02897986
#   0.0372673   0.06156594  0.00305658 -0.06269727 -0.02541712 -0.03125427
#  -0.02816655  0.02421703  0.04411192 -0.02808733 -0.01489838  0.01073323
#   0.03342851 -0.01343102  0.07707593  0.02091981 -0.0757606   0.11441958
#   0.03703819  0.09145663 -0.08731077  0.0452437   0.03622893  0.06327268
#   0.06928672  0.01057079  0.06594712  0.04595172  0.06522967  0.02393045
#  -0.01233057 -0.01162797 -0.06976354 -0.02707973 -0.03090204  0.05912431
#  -0.02156696 -0.02743239  0.0359214   0.02702921  0.05575405 -0.00090088
#   0.0865498   0.04035324  0.05530821  0.02641986  0.12085243  0.03504032
#  -0.00719036 -0.04159834 -0.0066008  -0.00687707]
# 句子 1666 的上下文向量:
#  [-0.03190576  0.1862281   0.03288961  0.07340989 -0.02201173 -0.20957279
#   0.11315902  0.3562122  -0.18671784 -0.20728023  0.02534046 -0.2736677
#  -0.03992966  0.03874481  0.08077326 -0.12817614  0.12882552 -0.00200489
#  -0.11917429 -0.41834396  0.0536819   0.04423872  0.10627127 -0.05938359
#  -0.07481353  0.04532912 -0.10267224  0.01170607 -0.13295928  0.04552384
#   0.10061608 -0.04817134  0.12432376 -0.21997733 -0.06349187  0.1454541
#   0.07559688  0.05777745 -0.06112069 -0.1490666   0.06526475 -0.17379412
#  -0.07485026  0.04530692  0.16187647 -0.137739   -0.22674398 -0.06587001
#   0.08858268  0.13648729  0.00729558 -0.14145687 -0.05854413 -0.07423306
#  -0.06480084  0.05849492  0.10325861 -0.0670187  -0.03687088  0.02426348
#   0.07331718 -0.03682628  0.1718108   0.05069447 -0.16433075  0.26109105
#   0.07919247  0.20013799 -0.20140144  0.10170914  0.08556639  0.1437382
#   0.15392648  0.01767422  0.14689869  0.10282265  0.14622372  0.05116572
#  -0.03022517 -0.02344134 -0.15802066 -0.05746561 -0.06974614  0.13029417
#  -0.04555279 -0.06957768  0.08167696  0.05788811  0.1261313   0.0035533
#   0.19302896  0.09109322  0.13127036  0.05569758  0.27605635  0.07541234
#  -0.01674822 -0.09041886 -0.01882661 -0.01442226]
# 句子 1667 的上下文向量:
#  [-0.00896372  0.04960866  0.00855398  0.02058932 -0.0072716  -0.06018644
#   0.03213039  0.10124347 -0.0523702  -0.05764924  0.00667982 -0.07856323
#  -0.01153571  0.01145091  0.02452842 -0.03603762  0.0340471  -0.00148545
#  -0.03319735 -0.11982691  0.01729179  0.01110143  0.03156611 -0.01518157
#  -0.02350633  0.01342922 -0.02733043  0.00299382 -0.03555012  0.01189318
#   0.02703601 -0.01266818  0.03610004 -0.06244979 -0.01688614  0.04083696
#   0.02301471  0.0173369  -0.01828035 -0.04063555  0.01921362 -0.04989989
#  -0.02174522  0.01197177  0.04895677 -0.03929421 -0.06359591 -0.01970028
#   0.02636382  0.04090405  0.00458442 -0.03964814 -0.01753872 -0.01945092
#  -0.02025944  0.01872993  0.02912623 -0.01994481 -0.01018816  0.00817261
#   0.02302747 -0.00958725  0.04622757  0.01535352 -0.04807506  0.07166718
#   0.02035098  0.05765097 -0.05638355  0.03116406  0.02409074  0.04159015
#   0.04425513  0.00597309  0.04322984  0.02909864  0.04536086  0.01378269
#  -0.00853639 -0.00728314 -0.04538275 -0.01690473 -0.02052821  0.03611808
#  -0.0134566  -0.01953523  0.02175949  0.01532526  0.03614699  0.00113526
#   0.05667808  0.02752635  0.03434049  0.0170169   0.07986968  0.02261579
#  -0.00619426 -0.02905489 -0.00479557 -0.00407443]
# 句子 1668 的上下文向量:
#  [-0.03337009  0.16549434  0.02390507  0.07152428 -0.01998198 -0.19196951
#   0.1102356   0.33128375 -0.18234721 -0.18863639  0.02477561 -0.24771267
#  -0.03319176  0.04115893  0.07541268 -0.12155826  0.12199481 -0.00183263
#  -0.10577603 -0.39966685  0.05961103  0.03584457  0.11032711 -0.05653572
#  -0.07353025  0.03942154 -0.09123458  0.01447193 -0.12305035  0.04617652
#   0.0972997  -0.03775008  0.12315544 -0.19583458 -0.06157853  0.14259775
#   0.06171685  0.04893956 -0.06517468 -0.13603571  0.07154652 -0.16288827
#  -0.06778505  0.04182456  0.1567366  -0.12493122 -0.20898888 -0.06705239
#   0.08430789  0.12419319  0.01004564 -0.12946123 -0.0590874  -0.06576861
#  -0.06752064  0.0534149   0.09361861 -0.06728464 -0.03834236  0.00839249
#   0.06946386 -0.03623917  0.16070895  0.04560511 -0.15998405  0.24654718
#   0.07601727  0.18636116 -0.19303066  0.10027902  0.07860227  0.13567477
#   0.14113685  0.02199882  0.14050093  0.09349769  0.14971623  0.05346297
#  -0.03010121 -0.01151953 -0.1437363  -0.05573077 -0.0721124   0.12589198
#  -0.0454462  -0.0681534   0.07930335  0.05451329  0.11432205  0.0029675
#   0.18400621  0.08382672  0.11548667  0.05045741  0.2557056   0.06728342
#  -0.01027771 -0.09012446 -0.01151324 -0.01065895]
# 句子 1669 的上下文向量:
#  [-0.01531371  0.06579994  0.01322059  0.02647387 -0.01227201 -0.07721791
#   0.04388632  0.1302293  -0.07102983 -0.0744689   0.00908823 -0.10265834
#  -0.01288013  0.01200756  0.02774939 -0.04639431  0.04995684 -0.00243738
#  -0.0454448  -0.15128681  0.02362288  0.01708204  0.03897914 -0.02146298
#  -0.02635166  0.01895108 -0.03431876  0.00207391 -0.04834975  0.02114658
#   0.03664509 -0.01914257  0.04680996 -0.07959205 -0.02502285  0.05564771
#   0.03026955  0.02204018 -0.02428752 -0.05620446  0.02423604 -0.06754735
#  -0.02491448  0.01392799  0.06134035 -0.04825872 -0.07980724 -0.02436253
#   0.03182385  0.04918106  0.00481002 -0.05269672 -0.02088962 -0.02702383
#  -0.02481165  0.0240306   0.04093034 -0.02322877 -0.01415847  0.00676939
#   0.02429519 -0.00858483  0.06265677  0.01788811 -0.06169112  0.09903801
#   0.0317446   0.07272857 -0.07059143  0.03750215  0.03338021  0.05436328
#   0.0561278   0.00880233  0.05261397  0.03662294  0.05484097  0.01734312
#  -0.00960885 -0.00684882 -0.05719454 -0.02320569 -0.02445552  0.04945016
#  -0.01363937 -0.02459105  0.03097636  0.02177186  0.0420136  -0.00187301
#   0.0710104   0.03408409  0.04552858  0.02276326  0.09863851  0.02782463
#  -0.0015774  -0.03342922 -0.00769884 -0.00421474]
# 句子 1670 的上下文向量:
#  [-2.58481205e-02  1.53165534e-01  3.25369872e-02  6.46396503e-02
#  -2.14055646e-02 -1.83213905e-01  1.01303093e-01  3.13002437e-01
#  -1.66158840e-01 -1.89962968e-01  2.05648858e-02 -2.40627289e-01
#  -3.59394364e-02  3.17213349e-02  7.68279061e-02 -1.11329474e-01
#   1.11308485e-01  2.58483668e-03 -9.91397798e-02 -3.70408207e-01
#   5.04239388e-02  3.70211601e-02  9.44765806e-02 -5.15090823e-02
#  -6.42869994e-02  4.56771441e-02 -8.84595439e-02  1.72397345e-02
#  -1.13439471e-01  4.27717753e-02  8.24744627e-02 -3.85169573e-02
#   1.12214185e-01 -1.90351903e-01 -5.65862991e-02  1.22267127e-01
#   6.36662841e-02  4.80106473e-02 -5.58457337e-02 -1.26672804e-01
#   6.13222979e-02 -1.48593545e-01 -6.24914616e-02  4.53716964e-02
#   1.44584775e-01 -1.23575784e-01 -1.97402939e-01 -5.87920286e-02
#   8.07457492e-02  1.21344171e-01  3.94273270e-03 -1.25439987e-01
#  -4.88604195e-02 -6.76049888e-02 -5.84845543e-02  5.51036410e-02
#   8.57484713e-02 -5.59786744e-02 -2.26142611e-02  2.33870912e-02
#   6.34041205e-02 -2.83229500e-02  1.52215555e-01  4.92545217e-02
#  -1.46828949e-01  2.30306581e-01  7.08984658e-02  1.80573106e-01
#  -1.77933812e-01  9.10140872e-02  8.13688636e-02  1.27371848e-01
#   1.40052602e-01  1.72038991e-02  1.30732954e-01  9.40300748e-02
#   1.36510476e-01  4.32813466e-02 -3.09619829e-02 -2.45400667e-02
#  -1.44329548e-01 -5.06077819e-02 -6.55665025e-02  1.19088233e-01
#  -3.84629034e-02 -5.93697987e-02  7.73670375e-02  4.81892973e-02
#   1.06939502e-01 -2.29752695e-04  1.72232911e-01  7.71205053e-02
#   1.12067878e-01  5.48810624e-02  2.41681635e-01  6.77325800e-02
#  -1.09865079e-02 -8.18860754e-02 -8.78325105e-03 -1.22568710e-02]
# 句子 1671 的上下文向量:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
